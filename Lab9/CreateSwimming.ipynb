# %%
import pandas as pd # pandas handles panel data
import json # Allows automatic conversion to json data format
from pymongo import MongoClient #We just want the MongoClient part today
from os.path import join

# %% [markdown]
# # # Structure the Swimming dataset into documents
#  This uses Python to convert a source file csv into a 1:few structure for MongoDB.
#  This program reads the full csv file into a dataframe called df.
#
# https://data.world/romanian-data/swimming-dataset-top-200-world-times/workspace/data-dictionary
#  The csv has been uploaded into your module in Brightspace.

# %% [markdown]
# ## Understanding your data
#
# There is a 'data dictionary' of sorts on the original website, but it doesn't tell us enough.

# %%
# Investigate the dataset that you are using.  First, load the dataset.

df = pd.read_csv(join('../../Datasets/','Swimming Database 2.csv'), encoding='latin-1')
# First, let's check the columns we have and make sure the names 
# are okay and we want all of them.
print("Columns in data frame")
print(df.columns)
# Then print the shape - in this case, the number of rows and columns.
print('DataFrame shape ',df.shape)
# Out:
# Columns in data frame
# Index(['Event Name', 'Swim time', 'Swim date', 'Event description',
#        'Team Code', 'Team Name', 'Athlete Full Name', 'Gender',
#        'Athlete birth date', 'Rank_Order', 'City', 'Country Code',
#        'Duration (hh:mm:ss:ff)'],
#       dtype='object')
# DataFrame shape  (5200, 13)

# %% [markdown]
# #### In this case, the column names have spaces, so we won't be able to use dot notation.  We'll replace the spaces by "_"

# %%
df.columns = list(map(lambda x: x.replace(" ", "_"), df.columns))

# %% [markdown]
# ### Make sure each attribute has the correct data  type

# %%
df.dtypes
# Out:
# Event_Name                object
# Swim_time                 object
# Swim_date                 object
# Event_description         object
# Team_Code                 object
# Team_Name                 object
# Athlete_Full_Name         object
# Gender                    object
# Athlete_birth_date        object
# Rank_Order                 int64
# City                      object
# Country_Code              object
# Duration_(hh:mm:ss:ff)    object
# dtype: object

# %%
df[['Event_Name',  'Event_description', 'Team_Code', 'Team_Name', 'Athlete_Full_Name', 'Gender','City', 'Country_Code' ]] =\
df[['Event_Name',  'Event_description', 'Team_Code', 'Team_Name', 'Athlete_Full_Name', 'Gender','City', 'Country_Code' ]].astype("string")

# %% [markdown]
# #### We still have two dates and two times - are the times the same?
# 'Swim_time', 'Swim_date','Athlete_birth_date','Duration_(hh:mm:ss:ff)'

# %%
df[['Swim_time','Duration_(hh:mm:ss:ff)']]
# Out:
#      Swim_time Duration_(hh:mm:ss:ff)
# 0        46.86              0:0:46:86
# 1        46.91              0:0:46:91
# 2        46.94              0:0:46:94
# 3        46.96              0:0:46:96
# 4        46.98              0:0:46:98
# ...        ...                    ...
# 5195  16:02.10             0:16:02:10
# 5196  16:02.15             0:16:02:15
# 5197  16:02.21             0:16:02:21
# 5198  16:02.26             0:16:02:26
# 5199  16:02.29             0:16:02:29
#
# [5200 rows x 2 columns]

# %% [markdown]
# #### In this case, they're the same.  Normally we could check programmatically, but not today.
# Rename Duration_(hh:mm:ss:ff) to Duration and drop Swim_time.

# %%
df = df.rename(columns={"Duration_(hh:mm:ss:ff)": "Duration"})
df = df.drop(columns=['Swim_time'])

# %%
df.columns
# Out:
# Index(['Event_Name', 'Swim_date', 'Event_description', 'Team_Code',
#        'Team_Name', 'Athlete_Full_Name', 'Gender', 'Athlete_birth_date',
#        'Rank_Order', 'City', 'Country_Code', 'Duration'],
#       dtype='object')

# %% [markdown]
# ## Dates and times
# Json conversion expects strings for dates and times, but the format needs to be correct.  If it is not, convert it to datetime, then back to string.

# %%
df['Athlete_birth_date'].head()
# Out:
# 0    9/15/2004
# 1    1/10/1987
# 2     5/1/1983
# 3    8/16/1996
# 4    9/15/2004
# Name: Athlete_birth_date, dtype: object

# %%
df['Athlete_birth_date']=pd.to_datetime(df['Athlete_birth_date'],format='%m/%d/%Y').dt.date
df['Athlete_birth_date']=df['Athlete_birth_date'].astype("string")

# %%
df['Athlete_birth_date'].head()
# Out:
# 0    2004-09-15
# 1    1987-01-10
# 2    1983-05-01
# 3    1996-08-16
# 4    2004-09-15
# Name: Athlete_birth_date, dtype: string

# %%
df['Swim_date']=pd.to_datetime(df['Swim_date'],format='%m/%d/%Y').dt.date
df['Swim_date']=df['Swim_date'].astype("string")

# %%
df.tail(2)
# Out:
#                        Event_Name   Swim_date  \
# 5198     Olympic Games Tokyo 2020  2021-07-26
# 5199  European Championships 2010  2010-08-14
#
#                     Event_description Team_Code Team_Name  \
# 5198  Women 1500 Freestyle LCM Female       HUN   Hungary
# 5199  Women 1500 Freestyle LCM Female       IRL   Ireland
#
#                 Athlete_Full_Name Gender Athlete_birth_date  Rank_Order  \
# 5198  MIHALYVARI-FARKAS, Viktoria      F         2003-11-26         199
# 5199              MURPHY, Grainne      F         1993-03-26         200
#
#           City Country_Code    Duration
# 5198     Tokyo          JPN  0:16:02:26
# 5199  Budapest          HUN  0:16:02:29

# %% [markdown]
# ### Exploring
#  - Let's look to see how many unique values there are in each column

# %%
print('Unique values')
print(df.nunique())
# Print the top five rows
print('Top 5 rows')
print(df.head(2))
print(df.tail(2))
# Out:
# Unique values
# Event_Name             476
# Swim_date             1001
# Event_description       26
# Team_Code               58
# Team_Name               58
# Athlete_Full_Name      716
# Gender                   2
# Athlete_birth_date     683
# Rank_Order             200
# City                   204
# Country_Code            50
# Duration              2964
# dtype: int64
# Top 5 rows
#                            Event_Name   Swim_date           Event_description  \
# 0         European Championships 2022  2022-08-13  Men 100 Freestyle LCM Male
# 1  13th FINA World Championships 2009  2009-07-30  Men 100 Freestyle LCM Male
#
#   Team_Code Team_Name   Athlete_Full_Name Gender Athlete_birth_date  \
# 0       ROU   Romania     POPOVICI, David      M         2004-09-15
# 1       BRA    Brazil  CIELO FILHO, Cesar      M         1987-01-10
#
#    Rank_Order  City Country_Code   Duration
# 0           1  Rome          ITA  0:0:46:86
# 1           2  Rome          ITA  0:0:46:91
#                        Event_Name   Swim_date  \
# 5198     Olympic Games Tokyo 2020  2021-07-26
# 5199  European Championships 2010  2010-08-14
#
#                     Event_description Team_Code Team_Name  \
# 5198  Women 1500 Freestyle LCM Female       HUN   Hungary
# 5199  Women 1500 Freestyle LCM Female       IRL   Ireland
#
#                 Athlete_Full_Name Gender Athlete_birth_date  Rank_Order  \
# 5198  MIHALYVARI-FARKAS, Viktoria      F         2003-11-26         199
# 5199              MURPHY, Grainne      F         1993-03-26         200
#
#           City Country_Code    Duration
# 5198     Tokyo          JPN  0:16:02:26
# 5199  Budapest          HUN  0:16:02:29

# %% [markdown]
# ### Promising relationships:
#  - It looks like we could consider grouping under any of the following:
#         - Team Code and Team Name (we should check that they have a 1:1 matching)
#         - Event Name (how does the Event_description correspond to this? Are they related?)
#         - Country and City?
#         - Athletes and their swims?

# %%
# |Isthere a 1:1 matching between team_code and team_name?
for i in  sorted(df.Team_Code.unique()):
    if len(df[df.Team_Code==i].Team_Name.unique())!=1:
        print(i)

# %% [markdown]
# #### Explore the relationship between event description and event name

# %%
print(df.Event_description.unique())
# Out:
# <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#        'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#    'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',        'Men 200 Butterfly LCM Male',
#        'Men 200 Backstroke LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',    'Women 200 Butterfly LCM Female',
#    'Women 200 Backstroke LCM Female',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 26, dtype: string

# %%
for i in sorted(df.Event_description.unique()):
       if len(df[df.Event_description==i].Event_Name.unique())!=1:
        print(i)
# Out:
# Men 100 Backstroke LCM Male
# Men 100 Breaststroke LCM Male
# Men 100 Butterfly LCM Male
# Men 100 Freestyle LCM Male
# Men 1500 Freestyle LCM Male
# Men 200 Backstroke LCM Male
# Men 200 Breaststroke LCM Male
# Men 200 Butterfly LCM Male
# Men 200 Freestyle LCM Male
# Men 200 Medley LCM Male
# Men 400 Freestyle LCM Male
# Men 400 Medley LCM Male
# Men 800 Freestyle LCM Male
# Women 100 Backstroke LCM Female
# Women 100 Breaststroke LCM Female
# Women 100 Butterfly LCM Female
# Women 100 Freestyle LCM Female
# Women 1500 Freestyle LCM Female
# Women 200 Backstroke LCM Female
# Women 200 Breaststroke LCM Female
# Women 200 Butterfly LCM Female
# Women 200 Freestyle LCM Female
# Women 200 Medley LCM Female
# Women 400 Freestyle LCM Female
# Women 400 Medley LCM Female
# Women 800 Freestyle LCM Female

# %% [markdown]
# #### Okay, they aren't 1:1.  Let's see what event descriptions are there for each event name

# %%
for i in sorted(df.Event_Name.unique()):
    print('\n', i, '\n', df[df.Event_Name==i].Event_description.unique())
# Out:
#  -
#  <StringArray>
# ['Women 100 Butterfly LCM Female', 'Women 200 Butterfly LCM Female',
#   'Men 200 Breaststroke LCM Male',        'Men 400 Medley LCM Male']
# Length: 4, dtype: string
#
#  10e Open de France de Natation Vichy Val d'Allier
#  <StringArray>
# ['Women 200 Medley LCM Female', 'Men 400 Medley LCM Male']
# Length: 2, dtype: string
#
#  10th FINA World Championships 2003
#  <StringArray>
# [     'Men 100 Butterfly LCM Male',      'Men 200 Freestyle LCM Male',
#       'Men 200 Butterfly LCM Male',         'Men 200 Medley LCM Male',
#       'Men 400 Freestyle LCM Male',         'Men 400 Medley LCM Male',
#       'Men 800 Freestyle LCM Male',     'Men 1500 Freestyle LCM Male',
#  'Women 1500 Freestyle LCM Female']
# Length: 9, dtype: string
#
#  10th Pan Pacific Championships 2006
#  <StringArray>
# [     'Men 200 Butterfly LCM Male',     'Men 200 Backstroke LCM Male',
#          'Men 200 Medley LCM Male',  'Women 200 Butterfly LCM Female',
#          'Men 400 Medley LCM Male', 'Women 1500 Freestyle LCM Female']
# Length: 6, dtype: string
#
#  10th Tokyo Swimming Championships
#  <StringArray>
# ['Women 100 Butterfly LCM Female', 'Men 200 Breaststroke LCM Male']
# Length: 2, dtype: string
#
#  11th Chinese National Games
#  <StringArray>
# ['Women 100 Freestyle LCM Female', 'Women 100 Butterfly LCM Female',
#  'Women 200 Butterfly LCM Female']
# Length: 3, dtype: string
#
#  11th FINA World Championships 2005
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',        'Men 200 Freestyle LCM Male',
#        'Men 200 Backstroke LCM Male',           'Men 200 Medley LCM Male',
#     'Women 200 Butterfly LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',           'Men 400 Medley LCM Male',
#         'Men 800 Freestyle LCM Male',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 11, dtype: string
#
#  11th Pan Pacific Championships 2010
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',    'Women 100 Freestyle LCM Female',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Freestyle LCM Male',
#         'Men 200 Butterfly LCM Male',       'Men 200 Backstroke LCM Male',
#            'Men 200 Medley LCM Male', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 13, dtype: string
#
#  12th Asian Games 1994
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  12th FINA World Championships 2007
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',    'Women 100 Freestyle LCM Female',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Freestyle LCM Male',
#         'Men 200 Butterfly LCM Male',       'Men 200 Backstroke LCM Male',
#            'Men 200 Medley LCM Male',    'Women 200 Freestyle LCM Female',
#     'Women 200 Butterfly LCM Female',   'Women 200 Backstroke LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 19, dtype: string
#
#  12th Pan Pacific Championships 2014
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',    'Women 100 Freestyle LCM Female',
#    'Women 100 Backstroke LCM Female',       'Men 200 Backstroke LCM Male',
#     'Women 200 Freestyle LCM Female',           'Men 200 Medley LCM Male',
#     'Women 200 Butterfly LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#    'Women 1500 Freestyle LCM Female']
# Length: 15, dtype: string
#
#  13th FINA World Championships 2009
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#     'Women 100 Freestyle LCM Female',       'Men 100 Backstroke LCM Male',
#     'Women 100 Butterfly LCM Female',   'Women 100 Backstroke LCM Female',
#      'Men 100 Breaststroke LCM Male', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',        'Men 200 Butterfly LCM Male',
#        'Men 200 Backstroke LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',    'Women 200 Butterfly LCM Female',
#    'Women 200 Backstroke LCM Female',       'Women 200 Medley LCM Female',
#      'Men 200 Breaststroke LCM Male', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 26, dtype: string
#
#  13th Pan Pacific Championships 2018
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',       'Men 100 Backstroke LCM Male',
#     'Women 100 Freestyle LCM Female',    'Women 100 Butterfly LCM Female',
#    'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',       'Men 200 Backstroke LCM Male',
#         'Men 200 Butterfly LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',   'Women 200 Backstroke LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 23, dtype: string
#
#  14th FINA World Championships 2011
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#        'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Freestyle LCM Male',
#        'Men 200 Backstroke LCM Male',        'Men 200 Butterfly LCM Male',
#            'Men 200 Medley LCM Male',    'Women 200 Freestyle LCM Female',
#    'Women 200 Backstroke LCM Female',    'Women 200 Butterfly LCM Female',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 24, dtype: string
#
#  15th Commonwealth Games 1994
#  <StringArray>
# ['Men 800 Freestyle LCM Male', 'Men 1500 Freestyle LCM Male']
# Length: 2, dtype: string
#
#  15th FINA World Championships 2013
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#     'Women 100 Freestyle LCM Female',    'Women 100 Butterfly LCM Female',
#    'Women 100 Backstroke LCM Female',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Freestyle LCM Male',
#        'Men 200 Backstroke LCM Male',        'Men 200 Butterfly LCM Male',
#     'Women 200 Freestyle LCM Female',           'Men 200 Medley LCM Male',
#     'Women 200 Butterfly LCM Female',   'Women 200 Backstroke LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 25, dtype: string
#
#  15th Pan American Games 2007
#  <StringArray>
# ['Men 400 Medley LCM Male']
# Length: 1, dtype: string
#
#  16th Asian Games 2010
#  <StringArray>
# [     'Men 200 Freestyle LCM Male',      'Men 200 Butterfly LCM Male',
#      'Men 200 Backstroke LCM Male',  'Women 200 Butterfly LCM Female',
#  'Women 200 Backstroke LCM Female',     'Women 200 Medley LCM Female',
#       'Men 400 Freestyle LCM Male',     'Women 400 Medley LCM Female',
#       'Men 800 Freestyle LCM Male',     'Men 1500 Freestyle LCM Male']
# Length: 10, dtype: string
#
#  16th Commonwealth Games 1998
#  <StringArray>
# ['Men 400 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  16th FINA World Championships 2015
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#        'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#    'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',        'Men 200 Butterfly LCM Male',
#        'Men 200 Backstroke LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',    'Women 200 Butterfly LCM Female',
#    'Women 200 Backstroke LCM Female',       'Women 200 Medley LCM Female',
#      'Men 200 Breaststroke LCM Male', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 26, dtype: string
#
#  16th Mediterranean Games 2009
#  <StringArray>
# [   'Men 100 Backstroke LCM Male', 'Women 400 Freestyle LCM Female',
#         'Men 400 Medley LCM Male']
# Length: 3, dtype: string
#
#  16th Pan American Games 2011
#  <StringArray>
# ['Men 100 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  17th Asian Games 2014
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',       'Men 100 Backstroke LCM Male',
#     'Women 100 Butterfly LCM Female',        'Men 200 Freestyle LCM Male',
#        'Men 200 Backstroke LCM Male',        'Men 200 Butterfly LCM Male',
#            'Men 200 Medley LCM Male',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',       'Men 1500 Freestyle LCM Male']
# Length: 14, dtype: string
#
#  17th Commonwealth Games 2002
#  <StringArray>
# ['Men 200 Freestyle LCM Male', 'Men 400 Freestyle LCM Male']
# Length: 2, dtype: string
#
#  17th FINA World Championships 2017
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#     'Women 100 Freestyle LCM Female',       'Men 100 Backstroke LCM Male',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#    'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',        'Men 200 Butterfly LCM Male',
#        'Men 200 Backstroke LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',    'Women 200 Butterfly LCM Female',
#    'Women 200 Backstroke LCM Female',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 26, dtype: string
#
#  17th Pan American Games 2015
#  <StringArray>
# [   'Women 100 Freestyle LCM Female', 'Women 100 Breaststroke LCM Female',
#            'Men 200 Medley LCM Male']
# Length: 3, dtype: string
#
#  18th Asian Games 2018
#  <StringArray>
# [     'Men 100 Butterfly LCM Male',     'Men 100 Backstroke LCM Male',
#   'Women 100 Butterfly LCM Female',   'Men 100 Breaststroke LCM Male',
#       'Men 200 Freestyle LCM Male',     'Men 200 Backstroke LCM Male',
#       'Men 200 Butterfly LCM Male',         'Men 200 Medley LCM Male',
#   'Women 200 Butterfly LCM Female',   'Men 200 Breaststroke LCM Male',
#      'Women 200 Medley LCM Female',      'Men 400 Freestyle LCM Male',
#   'Women 400 Freestyle LCM Female',         'Men 400 Medley LCM Male',
#      'Women 400 Medley LCM Female',  'Women 800 Freestyle LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 17, dtype: string
#
#  18th Commonwealth Games 2006
#  <StringArray>
# [   'Women 100 Freestyle LCM Female', 'Women 100 Breaststroke LCM Female',
#     'Women 200 Butterfly LCM Female', 'Women 200 Breaststroke LCM Female']
# Length: 4, dtype: string
#
#  18th FINA World Championships 2019
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#     'Women 100 Freestyle LCM Female',       'Men 100 Backstroke LCM Male',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#    'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',        'Men 200 Butterfly LCM Male',
#        'Men 200 Backstroke LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',   'Women 200 Backstroke LCM Female',
#     'Women 200 Butterfly LCM Female',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 26, dtype: string
#
#  18th Luxembourg Euro Meet 2016
#  <StringArray>
# ['Men 200 Breaststroke LCM Male', 'Women 400 Medley LCM Female']
# Length: 2, dtype: string
#
#  18th Mediterranean Games 2018
#  <StringArray>
# ['Men 1500 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  18th Pan American Games 2019
#  <StringArray>
# ['Men 200 Breaststroke LCM Male', 'Women 200 Breaststroke LCM Female']
# Length: 2, dtype: string
#
#  19th Commonwealth Games 2010
#  <StringArray>
# ['Women 100 Breaststroke LCM Female', 'Women 200 Medley LCM Female']
# Length: 2, dtype: string
#
#  19th FINA World Championships Budapest 2022
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#        'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',   'Women 100 Backstroke LCM Female',
#      'Men 100 Breaststroke LCM Male', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',        'Men 200 Butterfly LCM Male',
#        'Men 200 Backstroke LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',   'Women 200 Backstroke LCM Female',
#     'Women 200 Butterfly LCM Female',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 26, dtype: string
#
#  19th Luxembourg Euro Meet 2017
#  <StringArray>
# ['Men 100 Breaststroke LCM Male']
# Length: 1, dtype: string
#
#  1st Youth Swimming Championships
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  2001 Australian Championships & World Championship Trials
#  <StringArray>
# ['Men 200 Freestyle LCM Male', 'Men 800 Freestyle LCM Male']
# Length: 2, dtype: string
#
#  2002 Phillips66 Spring Nationals
#  <StringArray>
# ['Men 200 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  2011 Canada Cup
#  <StringArray>
# ['Women 100 Freestyle LCM Female', 'Women 100 Backstroke LCM Female']
# Length: 2, dtype: string
#
#  2011 International Competition Selection Trial
#  <StringArray>
# [   'Men 200 Backstroke LCM Male',     'Men 200 Butterfly LCM Male',
#  'Women 200 Butterfly LCM Female',  'Men 200 Breaststroke LCM Male']
# Length: 4, dtype: string
#
#  2011 JPN Open
#  <StringArray>
# ['Men 100 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  2011 Japan Open
#  <StringArray>
# ['Men 200 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  2011 Maria Lenk Trophy
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  2011 New South Wales Open Champs
#  <StringArray>
# ['Women 200 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  2011 Telstra Australian Swimming Championships
#  <StringArray>
# ['Women 200 Freestyle LCM Female', 'Women 200 Backstroke LCM Female']
# Length: 2, dtype: string
#
#  2012 AUS Invite
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  2012 EnergyAustralia Swimming
#  <StringArray>
# [     'Men 100 Freestyle LCM Male',      'Men 200 Butterfly LCM Male',
#  'Women 200 Backstroke LCM Female',     'Women 200 Medley LCM Female',
#   'Women 400 Freestyle LCM Female',     'Women 400 Medley LCM Female']
# Length: 6, dtype: string
#
#  2012 Miami Super Challenge
#  <StringArray>
# ['Men 400 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  2012 NSW State Open Championshps
#  <StringArray>
# ['Women 200 Butterfly LCM Female', 'Men 1500 Freestyle LCM Male']
# Length: 2, dtype: string
#
#  2012 ST TXLA Elite Invite
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  2012 Western States- AUS
#  <StringArray>
# ['Men 200 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  2013 BHP Billiton Aquatic Supe
#  <StringArray>
# ['Women 200 Medley LCM Female']
# Length: 1, dtype: string
#
#  2013 EnergyAustralia Swimming
#  <StringArray>
# [     'Men 100 Freestyle LCM Male', 'Women 200 Backstroke LCM Female',
#      'Women 200 Medley LCM Female',      'Men 400 Freestyle LCM Male',
#   'Women 400 Freestyle LCM Female',         'Men 400 Medley LCM Male',
#      'Men 1500 Freestyle LCM Male']
# Length: 7, dtype: string
#
#  2013 NSW State Open Championships
#  <StringArray>
# ['Men 200 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  2014 Amiens Golden Lanes
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  2014 BHP Billiton Aquatic Super Series
#  <StringArray>
# [    'Men 100 Freestyle LCM Male', 'Women 100 Freestyle LCM Female',
#         'Men 200 Medley LCM Male',        'Men 400 Medley LCM Male']
# Length: 4, dtype: string
#
#  2014 GU TWST Senior Invitational
#  <StringArray>
# [ 'Women 400 Freestyle LCM Female',  'Women 800 Freestyle LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  2014 Japan Open
#  <StringArray>
# ['Women 100 Breaststroke LCM Female', 'Men 400 Medley LCM Male']
# Length: 2, dtype: string
#
#  2014 MBC Cup Swimming Competition
#  <StringArray>
# ['Men 200 Freestyle LCM Male', 'Men 400 Freestyle LCM Male']
# Length: 2, dtype: string
#
#  2014 NSW State Open Championships
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',   'Women 200 Backstroke LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female']
# Length: 5, dtype: string
#
#  2014 Tokyo Invite
#  <StringArray>
# ['Men 200 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  2014 Victorian Open Championships
#  <StringArray>
# ['Men 100 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  2015 Tokyo City Championships
#  <StringArray>
# ['Men 200 Medley LCM Male']
# Length: 1, dtype: string
#
#  2016 Atlanta Classic Swim Meet
#  <StringArray>
# ['Women 200 Freestyle LCM Female', 'Women 400 Freestyle LCM Female',
#     'Women 400 Medley LCM Female']
# Length: 3, dtype: string
#
#  2016 CHN National Championships
#  <StringArray>
# ['Women 100 Freestyle LCM Female', 'Women 100 Butterfly LCM Female',
#     'Men 200 Backstroke LCM Male', 'Women 200 Butterfly LCM Female']
# Length: 4, dtype: string
#
#  2016 Konami Open
#  <StringArray>
# ['Women 200 Butterfly LCM Female',        'Men 400 Medley LCM Male',
#     'Women 400 Medley LCM Female']
# Length: 3, dtype: string
#
#  2017 NC SwimMAC UltraSwim
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  2017 National Games
#  <StringArray>
# [      'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#      'Men 100 Breaststroke LCM Male',        'Men 200 Freestyle LCM Male',
#        'Men 200 Backstroke LCM Male',           'Men 200 Medley LCM Male',
#     'Women 200 Butterfly LCM Female',     'Men 200 Breaststroke LCM Male',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',   'Women 1500 Freestyle LCM Female']
# Length: 14, dtype: string
#
#  2017 ST TXLA Speedo Southern Sectionals
#  <StringArray>
# ['Men 100 Butterfly LCM Male']
# Length: 1, dtype: string
#
#  2018 KONAMI OPEN
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  20th Commonwealth Games 2014
#  <StringArray>
# [    'Men 100 Breaststroke LCM Male',        'Men 200 Freestyle LCM Male',
#     'Women 200 Freestyle LCM Female',   'Women 200 Backstroke LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male']
# Length: 12, dtype: string
#
#  20th Luxembourg Euro Meet 2018
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  21st Commonwealth Games 2018
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#    'Women 100 Backstroke LCM Female',        'Men 200 Freestyle LCM Male',
#         'Men 200 Butterfly LCM Male',    'Women 200 Freestyle LCM Female',
#     'Women 200 Butterfly LCM Female',   'Women 200 Backstroke LCM Female',
#      'Men 200 Breaststroke LCM Male', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#        'Women 400 Medley LCM Female',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male']
# Length: 17, dtype: string
#
#  22nd Commonwealth Games 2022
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',    'Women 100 Butterfly LCM Female',
#    'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',   'Women 200 Backstroke LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male']
# Length: 17, dtype: string
#
#  22nd Luxembourg Euro Meet 2020
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  25th Summer Universiade 2009
#  <StringArray>
# [      'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#        'Men 200 Backstroke LCM Male',        'Men 200 Butterfly LCM Male',
#  'Women 200 Breaststroke LCM Female',        'Men 800 Freestyle LCM Male',
#        'Men 1500 Freestyle LCM Male']
# Length: 7, dtype: string
#
#  26th International Meeting Uster 2018
#  <StringArray>
# ['Women 100 Backstroke LCM Female']
# Length: 1, dtype: string
#
#  27th Summer Universiade 2013
#  <StringArray>
# [       'Men 100 Freestyle LCM Male', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',       'Men 200 Backstroke LCM Male']
# Length: 4, dtype: string
#
#  29th Summer Universiade 2017
#  <StringArray>
# [ 'Women 100 Freestyle LCM Female',      'Men 200 Butterfly LCM Male',
#      'Women 400 Medley LCM Female',      'Men 800 Freestyle LCM Male',
#   'Women 800 Freestyle LCM Female',     'Men 1500 Freestyle LCM Male',
#  'Women 1500 Freestyle LCM Female']
# Length: 7, dtype: string
#
#  30th Summer Universiade 2019
#  <StringArray>
# ['Men 100 Freestyle LCM Male', 'Women 100 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  31th Internationale Schwimmveranstaltung Gothaer & Friends
#  <StringArray>
# ['Men 1500 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  32th Meeting International de Montecarlo
#  <StringArray>
# [       'Men 200 Butterfly LCM Male',       'Men 200 Backstroke LCM Male',
#  'Women 200 Breaststroke LCM Female']
# Length: 3, dtype: string
#
#  3rd Pan Pacific Championships 1989
#  <StringArray>
# ['Women 800 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  44th Santa Clara International
#  <StringArray>
# ['Women 100 Breaststroke LCM Female',   'Women 200 Backstroke LCM Female',
#        'Women 200 Medley LCM Female']
# Length: 3, dtype: string
#
#  47th International Open Swimming Trophy
#  <StringArray>
# ['Women 400 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  49th International Trophy Settecolli
#  <StringArray>
# ['Men 200 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  4th FINA World Junior Swimming Championships 2013
#  <StringArray>
# ['Men 800 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  4th Pan Pacific Championships 1991
#  <StringArray>
# ['Men 800 Freestyle LCM Male']
# Length: 1, dtype: string
#  52nd International Trophy Settecolli
#  <StringArray>
# [   'Women 100 Butterfly LCM Female', 'Women 100 Breaststroke LCM Female',
#     'Women 200 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  53th International Trophy Settecolli
#  <StringArray>
# ['Women 100 Freestyle LCM Female', 'Women 200 Freestyle LCM Female',
#      'Men 200 Butterfly LCM Male',     'Men 400 Freestyle LCM Male',
#  'Women 400 Freestyle LCM Female',     'Men 800 Freestyle LCM Male']
# Length: 6, dtype: string
#
#  54th International Trophy Settecolli
#  <StringArray>
# ['Men 100 Breaststroke LCM Male',    'Men 200 Butterfly LCM Male',
#     'Men 400 Freestyle LCM Male',       'Men 400 Medley LCM Male',
#    'Men 1500 Freestyle LCM Male']
# Length: 5, dtype: string
#
#  55th International Trophy Settecolli
#  <StringArray>
# [   'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',   'Women 200 Backstroke LCM Female',
#  'Women 200 Breaststroke LCM Female',       'Women 400 Medley LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 10, dtype: string
#
#  56th International Trophy Settecolli
#  <StringArray>
# [  'Men 100 Breaststroke LCM Male',      'Men 200 Butterfly LCM Male',
#   'Women 200 Freestyle LCM Female',         'Men 200 Medley LCM Male',
#  'Women 200 Backstroke LCM Female',   'Men 200 Breaststroke LCM Male',
#      'Women 200 Medley LCM Female',         'Men 400 Medley LCM Male',
#   'Women 800 Freestyle LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 10, dtype: string
#
#  57th International Trophy Settecolli
#  <StringArray>
# [     'Men 400 Freestyle LCM Male',      'Men 800 Freestyle LCM Male',
#      'Men 1500 Freestyle LCM Male', 'Women 1500 Freestyle LCM Female']
# Length: 4, dtype: string
#
#  58th International Trophy Settecolli
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Butterfly LCM Male',
#      'Men 200 Breaststroke LCM Male',           'Men 400 Medley LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 7, dtype: string
#
#  5th EDF Swimming Open
#  <StringArray>
# ['Women 400 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  5th FINA World Junior Swimming Championships 2015
#  <StringArray>
# ['Women 200 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  64th Festival of Sport - Swimming Time Trial 2021 (50m)
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  67th Japan National Sports Festival - Swimming Com
#  <StringArray>
# ['Men 200 Breaststroke LCM Male', 'Men 400 Medley LCM Male']
# Length: 2, dtype: string
#
#  6th FINA World Championships 1991
#  <StringArray>
# ['Men 1500 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  6th FINA World Junior Swimming Championships 2017
#  <StringArray>
# [     'Men 100 Butterfly LCM Male',   'Men 100 Breaststroke LCM Male',
#       'Men 200 Butterfly LCM Male', 'Women 1500 Freestyle LCM Female']
# Length: 4, dtype: string
#
#  6th Milano City Trophy - 2016
#  <StringArray>
# ['Men 800 Freestyle LCM Male', 'Men 1500 Freestyle LCM Male']
# Length: 2, dtype: string
#
#  71th National Games - Swimming Competition
#  <StringArray>
# ['Men 200 Medley LCM Male']
# Length: 1, dtype: string
#
#  7th EDF Open Swimming
#  <StringArray>
# ['Men 100 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  7th FINA World Championships 1994
#  <StringArray>
# ['Women 100 Freestyle LCM Female',     'Men 400 Freestyle LCM Male',
#     'Men 1500 Freestyle LCM Male']
# Length: 3, dtype: string
#
#  7th FINA World Junior Swimming Championships 2019
#  <StringArray>
# [ 'Women 100 Freestyle LCM Female',      'Men 800 Freestyle LCM Male',
#      'Men 1500 Freestyle LCM Male', 'Women 1500 Freestyle LCM Female']
# Length: 4, dtype: string
#
#  7th Milano City Trophy - 2017
#  <StringArray>
# ['Men 1500 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  7th National City Games 2011
#  <StringArray>
# ['Women 400 Medley LCM Female']
# Length: 1, dtype: string
#
#  88th Dong-A Swimming Meet
#  <StringArray>
# ['Men 400 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  8th FINA World Junior Swimming Championships 2022
#  <StringArray>
# ['Men 100 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  8th Pan Pacific Championships 1999
#  <StringArray>
# ['Women 200 Butterfly LCM Female',     'Men 400 Freestyle LCM Male',
#     'Men 1500 Freestyle LCM Male']
# Length: 3, dtype: string
#
#  90th Inter College Swimming Championships
#  <StringArray>
# ['Men 100 Backstroke LCM Male', 'Men 200 Medley LCM Male']
# Length: 2, dtype: string
#
#  92nd Inter College Swimming Championships
#  <StringArray>
# ['Men 200 Medley LCM Male']
# Length: 1, dtype: string
#
#  9th FINA World Championships 2001
#  <StringArray>
# [     'Men 200 Freestyle LCM Male',      'Men 200 Butterfly LCM Male',
#   'Women 200 Butterfly LCM Female',      'Men 400 Freestyle LCM Male',
#       'Men 800 Freestyle LCM Male',     'Men 1500 Freestyle LCM Male',
#  'Women 1500 Freestyle LCM Female']
# Length: 7, dtype: string
#
#  9th French Swimming Open
#  <StringArray>
# [   'Women 200 Freestyle LCM Female', 'Women 200 Breaststroke LCM Female',
#        'Women 400 Medley LCM Female']
# Length: 3, dtype: string
#
#  9th Pan Pacific Championships 2002
#  <StringArray>
# [ 'Men 200 Freestyle LCM Male',  'Men 800 Freestyle LCM Male',
#  'Men 1500 Freestyle LCM Male']
# Length: 3, dtype: string
#
#  ASA Youth MC & Open Champs 2014
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  Amsterdam Cup
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Amsterdam Swim Cup 2013
#  <StringArray>
# ['Women 400 Medley LCM Female']
# Length: 1, dtype: string
#
#  Amsterdam Swim Cup 2014
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Amsterdam Swim Cup 2015
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Antwerp Diamond Speedo Race
#  <StringArray>
# ['Men 100 Breaststroke LCM Male', 'Men 200 Breaststroke LCM Male']
# Length: 2, dtype: string
#
#  Aon New Zealand National Championships (50m)
#  <StringArray>
# ['Men 400 Medley LCM Male']
# Length: 1, dtype: string
#
#  Aquatic Super Series 2016
#  <StringArray>
# ['Men 100 Freestyle LCM Male', 'Women 200 Breaststroke LCM Female']
# Length: 2, dtype: string
#
#  Arena Grand Prix (Mesa)
#  <StringArray>
# ['Women 800 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Arena PSS - Indianapolis 2016
#  <StringArray>
# ['Men 100 Backstroke LCM Male', 'Women 400 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  Arena Pro Series Minneapolis 2015
#  <StringArray>
# [    'Men 100 Backstroke LCM Male',  'Women 200 Freestyle LCM Female',
#  'Women 200 Backstroke LCM Female',  'Women 400 Freestyle LCM Female',
#   'Women 800 Freestyle LCM Female']
# Length: 5, dtype: string
#
#  Arena Pro Series Orlando 2016
#  <StringArray>
# ['Women 200 Freestyle LCM Female', 'Women 200 Breaststroke LCM Female']
# Length: 2, dtype: string
#
#  Arena Pro Swim Atlanta 2017
#  <StringArray>
# [    'Men 400 Freestyle LCM Male', 'Women 400 Freestyle LCM Female',
#         'Men 400 Medley LCM Male', 'Women 800 Freestyle LCM Female']
# Length: 4, dtype: string
#
#  Arena Pro Swim Indianapolis 2017
#  <StringArray>
# ['Men 100 Breaststroke LCM Male',   'Men 200 Backstroke LCM Male',
#        'Men 400 Medley LCM Male']
# Length: 3, dtype: string
#
#  Arena Pro Swim Mesa 2017
#  <StringArray>
# ['Women 400 Freestyle LCM Female',        'Men 400 Medley LCM Male',
#  'Women 800 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  Arena Pro Swim Series - Mesa 2015
#  <StringArray>
# [ 'Women 400 Freestyle LCM Female',  'Women 800 Freestyle LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  Arena Pro Swim Series Charlotte 2015
#  <StringArray>
# ['Women 200 Medley LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  Arena Pro Swim Series Santa Clara 2016
#  <StringArray>
# [   'Men 100 Backstroke LCM Male',     'Men 200 Freestyle LCM Male',
#     'Men 200 Backstroke LCM Male',     'Men 400 Freestyle LCM Male',
#  'Women 800 Freestyle LCM Female']
# Length: 5, dtype: string
#
#  Arena Pro Swim Series Santa Clara 2017
#  <StringArray>
# ['Women 200 Freestyle LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  Arena Pro Swim Series at Santa Clara 2015
#  <StringArray>
# ['Women 200 Freestyle LCM Female',    'Women 200 Medley LCM Female',
#     'Women 400 Medley LCM Female']
# Length: 3, dtype: string
#
#  Asian Swimming Championships 2009
#  <StringArray>
# ['Women 200 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  Asian Swimming Championships 2012
#  <StringArray>
# [ 'Men 200 Freestyle LCM Male',  'Men 400 Freestyle LCM Male',
#  'Men 1500 Freestyle LCM Male']
# Length: 3, dtype: string
#
#  Asian Swimming Championships 2016
#  <StringArray>
# [   'Men 200 Freestyle LCM Male',    'Men 200 Butterfly LCM Male',
#    'Men 200 Backstroke LCM Male',       'Men 200 Medley LCM Male',
#  'Men 200 Breaststroke LCM Male',    'Men 400 Freestyle LCM Male',
#        'Men 400 Medley LCM Male']
# Length: 7, dtype: string
#
#  Atlanta Classic 2021
#  <StringArray>
# [     'Men 100 Butterfly LCM Male', 'Women 100 Backstroke LCM Female',
#  'Women 200 Backstroke LCM Female']
# Length: 3, dtype: string
#
#  Atlanta Classis Swim Meet 2019
#  <StringArray>
# ['Men 100 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  Atlanta PSS 2018
#  <StringArray>
# [     'Men 100 Butterfly LCM Male',  'Women 100 Butterfly LCM Female',
#      'Men 200 Backstroke LCM Male', 'Women 200 Backstroke LCM Female',
#   'Women 400 Freestyle LCM Female',         'Men 400 Medley LCM Male',
#   'Women 800 Freestyle LCM Female']
# Length: 7, dtype: string
#
#  Austin Grand Prix 2013
#  <StringArray>
# ['Women 200 Backstroke LCM Female']
# Length: 1, dtype: string
#
#  Austin PSS 2018
#  <StringArray>
# ['Men 400 Medley LCM Male']
# Length: 1, dtype: string
#
#  Australian Age Swimming Championships 2022
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Australian National Championships (50m)
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',    'Women 100 Freestyle LCM Female',
#        'Men 100 Backstroke LCM Male',    'Women 100 Butterfly LCM Female',
#    'Women 100 Backstroke LCM Female',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Freestyle LCM Male',
#     'Women 200 Freestyle LCM Female',       'Men 200 Backstroke LCM Male',
#    'Women 200 Backstroke LCM Female',    'Women 200 Butterfly LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 23, dtype: string
#
#  Australian Olympic Swimming Trials
#  <StringArray>
# [    'Men 200 Freestyle LCM Male', 'Women 200 Butterfly LCM Female',
#      'Men 400 Freestyle LCM Male']
# Length: 3, dtype: string
#
#  Australian Olympic Trials 1992
#  <StringArray>
# ['Men 1500 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  BHP Aquatic Super Series 2015
#  <StringArray>
# ['Women 100 Backstroke LCM Female', 'Men 200 Backstroke LCM Male']
# Length: 2, dtype: string
#
#  Belarus National Championships (50m)
#  <StringArray>
# ['Men 100 Breaststroke LCM Male']
# Length: 1, dtype: string
#
#  Bergen Swim Festival 2015
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Bergen Swim Festival 2017
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  Bergen Swim Festival 2018
#  <StringArray>
# ['Women 100 Butterfly LCM Female',        'Men 200 Medley LCM Male',
#  'Women 800 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  Bergen Swim Festival 2019
#  <StringArray>
# ['Women 100 Butterfly LCM Female', 'Men 1500 Freestyle LCM Male']
# Length: 2, dtype: string
#
#  Berlin Swim Open
#  <StringArray>
# ['Men 800 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  Borac Telegroup Grand Challenge 2021
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Brazilian National Championships (50m)
#  <StringArray>
# ['Men 100 Freestyle LCM Male', 'Men 100 Butterfly LCM Male']
# Length: 2, dtype: string
#
#  British Championships 2016
#  <StringArray>
# [    'Men 100 Breaststroke LCM Male',        'Men 200 Freestyle LCM Male',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#        'Women 400 Medley LCM Female']
# Length: 7, dtype: string
#
#  British Gas National Championships (50m)
#  <StringArray>
# ['Women 100 Breaststroke LCM Female',    'Women 200 Butterfly LCM Female',
#    'Women 200 Backstroke LCM Female',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female',    'Women 400 Freestyle LCM Female',
#     'Women 800 Freestyle LCM Female',   'Women 1500 Freestyle LCM Female']
# Length: 8, dtype: string
#
#  British Gas Swimming Championships 2012
#  <StringArray>
# ['Women 100 Freestyle LCM Female', 'Women 100 Butterfly LCM Female',
#  'Women 200 Freestyle LCM Female', 'Women 200 Butterfly LCM Female',
#  'Women 400 Freestyle LCM Female',    'Women 400 Medley LCM Female',
#  'Women 800 Freestyle LCM Female']
# Length: 7, dtype: string
#
#  British National Championships (50m)
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',    'Women 100 Freestyle LCM Female',
#      'Men 100 Breaststroke LCM Male',        'Men 200 Freestyle LCM Male',
#            'Men 200 Medley LCM Male',    'Women 200 Butterfly LCM Female',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#         'Men 400 Freestyle LCM Male',    'Women 400 Freestyle LCM Female',
#            'Men 400 Medley LCM Male',       'Women 400 Medley LCM Female',
#        'Men 1500 Freestyle LCM Male']
# Length: 13, dtype: string
#
#  British National Swimming Championships (50m)
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',     'Men 100 Breaststroke LCM Male',
#    'Women 100 Backstroke LCM Female',        'Men 200 Freestyle LCM Male',
#            'Men 200 Medley LCM Male',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#        'Men 1500 Freestyle LCM Male']
# Length: 9, dtype: string
#
#  British Swimming Championships (50m)
#  <StringArray>
# [   'Men 100 Freestyle LCM Male', 'Men 100 Breaststroke LCM Male',
#        'Men 200 Medley LCM Male', 'Men 200 Breaststroke LCM Male',
#        'Men 400 Medley LCM Male',   'Men 1500 Freestyle LCM Male']
# Length: 6, dtype: string
#
#  British Swimming Glasgow Open Meet
#  <StringArray>
# [   'Men 100 Butterfly LCM Male', 'Men 100 Breaststroke LCM Male',
#    'Women 200 Medley LCM Female']
# Length: 3, dtype: string
#
#  Bulgarian Open Team Championships
#  <StringArray>
# ['Men 100 Butterfly LCM Male']
# Length: 1, dtype: string
#
#  Bundesstuetzpunktwettkampf Magdeburg 2021
#  <StringArray>
# ['Men 1500 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  CA MVN March  Senior I 2015 (50m)
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  CA SMC 2007
#  <StringArray>
# ['Women 1500 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Campionato Italiano Assoluto UnipolSai 2018
#  <StringArray>
# [     'Men 800 Freestyle LCM Male',     'Men 1500 Freestyle LCM Male',
#  'Women 1500 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  Canadian Olympic Swimming Trials 2016
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Canadian Swimming Trials 2017
#  <StringArray>
# [ 'Women 100 Freestyle LCM Female', 'Women 100 Backstroke LCM Female',
#  'Women 200 Backstroke LCM Female',     'Women 200 Medley LCM Female']
# Length: 4, dtype: string
#
#  Canadian Swimming Trials 2018
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Canadian Swimming Trials 2019
#  <StringArray>
# [  'Women 100 Backstroke LCM Female',   'Women 200 Backstroke LCM Female',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#        'Women 400 Medley LCM Female']
# Length: 5, dtype: string
#
#  Canadian Swimming Trials 2022
#  <StringArray>
# [     'Men 100 Butterfly LCM Male', 'Women 100 Backstroke LCM Female',
#   'Women 200 Freestyle LCM Female',  'Women 400 Freestyle LCM Female',
#      'Women 400 Medley LCM Female']
# Length: 5, dtype: string
#
#  Canadian World Championship Trials
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  Canadian World Championships Trials 2013
#  <StringArray>
# ['Men 800 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  Central Zone Section 3 Spring Speedo Sectionals 2021
#  <StringArray>
# ['Women 100 Breaststroke LCM Female', 'Women 200 Breaststroke LCM Female']
# Length: 2, dtype: string
#
#  Charlotte PSS 2016
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  China Autumn Nationals
#  <StringArray>
# ['Men 100 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  Chinese National Championships (50m)
#  <StringArray>
# [      'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Freestyle LCM Male',
#     'Women 200 Freestyle LCM Female',       'Men 200 Backstroke LCM Male',
#            'Men 200 Medley LCM Male',    'Women 200 Butterfly LCM Female',
#    'Women 200 Backstroke LCM Female',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 21, dtype: string
#
#  Chinese Nationals
#  <StringArray>
# [    'Men 100 Backstroke LCM Male',     'Men 200 Backstroke LCM Male',
#          'Men 200 Medley LCM Male', 'Women 200 Backstroke LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 5, dtype: string
#
#  Columbus PSS 2018
#  <StringArray>
# ['Men 200 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  ConocoPhillips Nationals 2003
#  <StringArray>
# ['Men 200 Medley LCM Male']
# Length: 1, dtype: string
#
#  Counsilman Classic 2019
#  <StringArray>
# ['Women 100 Backstroke LCM Female']
# Length: 1, dtype: string
#
#  Czech National Championships (50m)
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Danish National Championships (50m)
#  <StringArray>
# ['Women 200 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  Danish Open
#  <StringArray>
# ['Women 200 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  Danish Open 2014
#  <StringArray>
# ['Women 200 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  Danish Open 2015
#  <StringArray>
# ['Women 200 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  Duel in the Pool 2022
#  <StringArray>
# ['Men 100 Butterfly LCM Male', 'Women 100 Backstroke LCM Female']
# Length: 2, dtype: string
#
#  Edinburgh International Swim Meet
#  <StringArray>
# ['Men 100 Breaststroke LCM Male', 'Women 100 Breaststroke LCM Female']
# Length: 2, dtype: string
#
#  Eindhoven Qualification Meet
#  <StringArray>
# ['Men 100 Breaststroke LCM Male', 'Women 100 Backstroke LCM Female']
# Length: 2, dtype: string
#
#  Eindhoven Swim Cup
#  <StringArray>
# ['Women 200 Freestyle LCM Female', 'Women 200 Breaststroke LCM Female']
# Length: 2, dtype: string
#
#  Eindhoven Swim Cup / Dutch Championships1
#  <StringArray>
# ['Women 100 Freestyle LCM Female', 'Women 200 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  Energy Standard Cup 2016
#  <StringArray>
# ['Men 200 Backstroke LCM Male', 'Women 400 Medley LCM Female']
# Length: 2, dtype: string
#
#  Energy for Swim 2017
#  <StringArray>
# ['Women 200 Freestyle LCM Female',     'Men 400 Freestyle LCM Male',
#         'Men 400 Medley LCM Male']
# Length: 3, dtype: string
#
#  European Championships 1987
#  <StringArray>
# ['Women 800 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  European Championships 1991
#  <StringArray>
# ['Women 200 Backstroke LCM Female']
# Length: 1, dtype: string
#
#  European Championships 1995
#  <StringArray>
# ['Women 200 Backstroke LCM Female']
# Length: 1, dtype: string
#
#  European Championships 2000
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  European Championships 2002
#  <StringArray>
# [    'Men 100 Freestyle LCM Male', 'Women 100 Freestyle LCM Female',
#      'Men 200 Freestyle LCM Male', 'Women 200 Butterfly LCM Female',
#     'Women 400 Medley LCM Female']
# Length: 5, dtype: string
#
#  European Championships 2004
#  <StringArray>
# ['Women 200 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  European Championships 2006
#  <StringArray>
# ['Women 100 Freestyle LCM Female',    'Men 200 Backstroke LCM Male',
#  'Women 400 Freestyle LCM Female',        'Men 400 Medley LCM Male',
#  'Women 800 Freestyle LCM Female']
# Length: 5, dtype: string
#
#  European Championships 2008
#  <StringArray>
# [     'Men 100 Freestyle LCM Male',  'Women 100 Freestyle LCM Female',
#       'Men 200 Butterfly LCM Male',  'Women 200 Butterfly LCM Female',
#   'Women 400 Freestyle LCM Female',         'Men 400 Medley LCM Male',
#      'Men 1500 Freestyle LCM Male', 'Women 1500 Freestyle LCM Female']
# Length: 8, dtype: string
#
#  European Championships 2010
#  <StringArray>
# [    'Men 100 Backstroke LCM Male',      'Men 200 Freestyle LCM Male',
#   'Women 200 Freestyle LCM Female',  'Women 200 Butterfly LCM Female',
#  'Women 200 Backstroke LCM Female',         'Men 400 Medley LCM Male',
#      'Women 400 Medley LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 8, dtype: string
#
#  European Championships 2012
#  <StringArray>
# ['Men 200 Backstroke LCM Male',     'Men 200 Medley LCM Male',
#  'Women 400 Medley LCM Female', 'Men 1500 Freestyle LCM Male']
# Length: 4, dtype: string
#
#  European Championships 2014
#  <StringArray>
# [   'Women 100 Freestyle LCM Female',    'Women 100 Butterfly LCM Female',
#      'Men 100 Breaststroke LCM Male',    'Women 200 Butterfly LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',    'Women 400 Freestyle LCM Female',
#        'Women 400 Medley LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 13, dtype: string
#
#  European Championships 2016
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',    'Women 100 Freestyle LCM Female',
# ...
#  <StringArray>
# ['Women 100 Breaststroke LCM Female',    'Women 200 Freestyle LCM Female',
#     'Women 400 Freestyle LCM Female',    'Women 800 Freestyle LCM Female']
# Length: 4, dtype: string
#
#  Santa Clara Swim Club International Meet 2019
#  <StringArray>
# ['Women 200 Butterfly LCM Female', 'Women 400 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  Scottish Gas National Championships (50m)
#  <StringArray>
# ['Men 200 Breaststroke LCM Male']
# Length: 1, dtype: string
#
#  Scottish National Championships (50m)
#  <StringArray>
# ['Women 200 Medley LCM Female']
# Length: 1, dtype: string
#
#  Sheffield Premier Meet
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  Singapore Swim Stars
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  South Africa Grand Prix No2
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  South Africa Invitational Aquatic Championships 2021
#  <StringArray>
# ['Women 100 Breaststroke LCM Female', 'Women 200 Breaststroke LCM Female']
# Length: 2, dtype: string
#
#  South African National Championships (50m)
#  <StringArray>
# ['Women 100 Breaststroke LCM Female', 'Men 200 Butterfly LCM Male']
# Length: 2, dtype: string
#
#  Spain Junior  National Championships (50m)
#  <StringArray>
# ['Women 1500 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Spanish Junior National Championships (50m)
#  <StringArray>
# ['Women 1500 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Spanish National Championships (50m)
#  <StringArray>
# ['Women 400 Medley LCM Female']
# Length: 1, dtype: string
#
#  Spanish Open Championships
#  <StringArray>
# ['Women 200 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  Spanish Open National Championships
#  <StringArray>
# ['Women 200 Butterfly LCM Female', 'Women 400 Medley LCM Female']
# Length: 2, dtype: string
#
#  Spanish Open Spring Swimming Championships
#  <StringArray>
# ['Women 400 Medley LCM Female']
# Length: 1, dtype: string
#
#  Spanish Open Spring Swimming Championships
#  <StringArray>
# [ 'Women 200 Butterfly LCM Female',     'Women 400 Medley LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  Spanish Open Swimming Championships
#  <StringArray>
# [ 'Women 200 Butterfly LCM Female',     'Women 400 Medley LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  Spring Spanish Championships
#  <StringArray>
# ['Women 200 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  Super Speedo Grand Prix
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  Swedish Grand Prix 2
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Swedish Grand Prix 3
#  <StringArray>
# ['Women 200 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Swedish National Championships (50m)
#  <StringArray>
# ['Women 100 Butterfly LCM Female', 'Women 200 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  Swim Cup 2013
#  <StringArray>
# ['Women 400 Medley LCM Female']
# Length: 1, dtype: string
#
#  Swim Cup Eindhoven 2012
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Swim England Winter Champs 2017
#  <StringArray>
# ['Women 200 Backstroke LCM Female']
# Length: 1, dtype: string
#
#  Swim Open Stockholm
#  <StringArray>
# ['Women 100 Butterfly LCM Female', 'Women 200 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  Swim Open Stockholm 2017
#  <StringArray>
# ['Women 100 Butterfly LCM Female', 'Women 200 Freestyle LCM Female',
#   'Men 200 Breaststroke LCM Male',        'Men 400 Medley LCM Male']
# Length: 4, dtype: string
#
#  Swimcup Amsterdam
#  <StringArray>
# [   'Women 100 Freestyle LCM Female',     'Men 100 Breaststroke LCM Male',
#      'Men 200 Breaststroke LCM Male', 'Women 200 Breaststroke LCM Female']
# Length: 4, dtype: string
#
#  Swimmeet Amsterdam
#  <StringArray>
# ['Men 100 Breaststroke LCM Male', 'Men 200 Breaststroke LCM Male']
# Length: 2, dtype: string
#
#  Swimming Australia Grand Prix
#  <StringArray>
# ['Women 1500 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Swimming Australia Grand Prix 2016
#  <StringArray>
# [      'Men 200 Backstroke LCM Male', 'Women 200 Breaststroke LCM Female',
#     'Women 800 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  Swimming QLD Prep meet
#  <StringArray>
# ['Women 100 Backstroke LCM Female', 'Women 200 Backstroke LCM Female']
# Length: 2, dtype: string
#
#  Swiss National Championships (50m)
#  <StringArray>
# ['Women 100 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  Sydney Open 2021
#  <StringArray>
# [ 'Women 100 Butterfly LCM Female', 'Women 100 Backstroke LCM Female',
#  'Women 200 Backstroke LCM Female',   'Men 200 Breaststroke LCM Male',
#      'Women 200 Medley LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 6, dtype: string
#
#  Sydney Open Meet 2019
#  <StringArray>
# ['Women 200 Backstroke LCM Female', 'Women 200 Medley LCM Female']
# Length: 2, dtype: string
#
#  TAC Spring Invitational 2021 (50m)
#  <StringArray>
# [ 'Women 100 Freestyle LCM Female',  'Women 100 Butterfly LCM Female',
#  'Women 100 Backstroke LCM Female']
# Length: 3, dtype: string
#
#  TT - TYR Pro Swim Series 2018
#  <StringArray>
# ['Men 100 Butterfly LCM Male']
# Length: 1, dtype: string
#
#  TYR Pro Swim Series Bloomington 2019
#  <StringArray>
# [  'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#     'Women 200 Freestyle LCM Female',   'Women 200 Backstroke LCM Female',
#  'Women 200 Breaststroke LCM Female',    'Women 400 Freestyle LCM Female',
#     'Women 800 Freestyle LCM Female']
# Length: 7, dtype: string
#
#  TYR Pro Swim Series Clovis 2019
#  <StringArray>
# ['Men 200 Butterfly LCM Male', 'Women 1500 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  TYR Pro Swim Series Des Moines 2019
#  <StringArray>
# ['Women 400 Freestyle LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  TYR Pro Swim Series Des Moines 2020
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',       'Men 100 Backstroke LCM Male',
#     'Women 100 Freestyle LCM Female',   'Women 100 Backstroke LCM Female',
#  'Women 100 Breaststroke LCM Female',    'Women 200 Freestyle LCM Female',
#        'Men 200 Backstroke LCM Male',           'Men 200 Medley LCM Male',
#     'Women 200 Butterfly LCM Female',   'Women 200 Backstroke LCM Female',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#     'Women 400 Freestyle LCM Female',       'Women 400 Medley LCM Female',
#     'Women 800 Freestyle LCM Female',   'Women 1500 Freestyle LCM Female']
# Length: 16, dtype: string
#
#  TYR Pro Swim Series Greenboro 2019
#  <StringArray>
# ['Women 200 Freestyle LCM Female', 'Women 400 Freestyle LCM Female',
#  'Women 800 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  TYR Pro Swim Series Indianapolis 2021
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',    'Women 100 Freestyle LCM Female',
#      'Men 100 Breaststroke LCM Male',   'Women 100 Backstroke LCM Female',
#  'Women 100 Breaststroke LCM Female',           'Men 200 Medley LCM Male',
#     'Women 200 Butterfly LCM Female',   'Women 200 Backstroke LCM Female',
#  'Women 200 Breaststroke LCM Female',   'Women 1500 Freestyle LCM Female']
# Length: 10, dtype: string
#
#  TYR Pro Swim Series Knoxville 2019
#  <StringArray>
# [ 'Women 200 Freestyle LCM Female',  'Women 400 Freestyle LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  TYR Pro Swim Series Knoxville 2020
#  <StringArray>
# ['Women 100 Backstroke LCM Female', 'Women 200 Backstroke LCM Female',
#  'Women 1500 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  TYR Pro Swim Series Mission Viejo 2021
#  <StringArray>
# ['Women 100 Breaststroke LCM Female',    'Women 200 Freestyle LCM Female',
#     'Women 200 Butterfly LCM Female',   'Women 200 Backstroke LCM Female',
#  'Women 200 Breaststroke LCM Female',    'Women 400 Freestyle LCM Female',
#     'Women 800 Freestyle LCM Female',   'Women 1500 Freestyle LCM Female']
# Length: 8, dtype: string
#
#  TYR Pro Swim Series Richmond 2019
#  <StringArray>
# ['Women 100 Backstroke LCM Female',  'Women 400 Freestyle LCM Female',
#   'Women 800 Freestyle LCM Female']
# Length: 3, dtype: string
#
#  TYR Pro Swim Series San Antonio 2021
#  <StringArray>
# ['Women 800 Freestyle LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  TYR Pro Swim Series San Antonio 2022
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',   'Women 100 Backstroke LCM Female',
#  'Women 100 Breaststroke LCM Female',    'Women 200 Freestyle LCM Female',
#            'Men 200 Medley LCM Male',           'Men 400 Medley LCM Male']
# Length: 6, dtype: string
#
#  TYR Pro Swim Series Westmont 2022
#  <StringArray>
# [   'Women 100 Butterfly LCM Female',    'Women 200 Butterfly LCM Female',
#    'Women 200 Backstroke LCM Female', 'Women 200 Breaststroke LCM Female',
#     'Women 400 Freestyle LCM Female',   'Women 1500 Freestyle LCM Female']
# Length: 6, dtype: string
#
#  Take5 HP Event
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  Telstra Australian National Championships (50m)
#  <StringArray>
# ['Women 100 Breaststroke LCM Female', 'Men 200 Butterfly LCM Male']
# Length: 2, dtype: string
#
#  The National Games
#  <StringArray>
# [   'Women 100 Freestyle LCM Female',    'Women 100 Butterfly LCM Female',
#      'Men 100 Breaststroke LCM Male', 'Women 100 Breaststroke LCM Female',
#     'Women 200 Freestyle LCM Female',        'Men 200 Butterfly LCM Male',
#            'Men 200 Medley LCM Male',    'Women 200 Butterfly LCM Female',
#  'Women 200 Breaststroke LCM Female',    'Women 400 Freestyle LCM Female',
#     'Women 800 Freestyle LCM Female',   'Women 1500 Freestyle LCM Female']
# Length: 12, dtype: string
#
#  Torneio Open CBDA-Correios
#  <StringArray>
# ['Men 200 Freestyle LCM Male']
# Length: 1, dtype: string
#
#  Toyota US Open 2020
#  <StringArray>
# ['Women 100 Butterfly LCM Female']
# Length: 1, dtype: string
#
#  Toyota US Open 2021
#  <StringArray>
# ['Women 100 Backstroke LCM Female',  'Women 200 Freestyle LCM Female',
#  'Women 200 Backstroke LCM Female',  'Women 400 Freestyle LCM Female',
#   'Women 800 Freestyle LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 6, dtype: string
#
#  US National Championships (50m)
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',       'Men 100 Backstroke LCM Male',
#     'Women 100 Freestyle LCM Female',    'Women 100 Butterfly LCM Female',
#    'Women 100 Backstroke LCM Female',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Freestyle LCM Male',
#         'Men 200 Butterfly LCM Male',       'Men 200 Backstroke LCM Male',
#     'Women 200 Freestyle LCM Female',           'Men 200 Medley LCM Male',
#    'Women 200 Backstroke LCM Female',    'Women 200 Butterfly LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',        'Men 800 Freestyle LCM Male',
#     'Women 800 Freestyle LCM Female',       'Men 1500 Freestyle LCM Male',
#    'Women 1500 Freestyle LCM Female']
# Length: 25, dtype: string
#
#  US National Winter Championships (50m)
#  <StringArray>
# ['Men 100 Backstroke LCM Male']
# Length: 1, dtype: string
#
#  US Nationals & Pan Pacific Trials
#  <StringArray>
# ['Women 1500 Freestyle LCM Female']
# Length: 1, dtype: string
#
#  US Olympic Team Trials
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',       'Men 100 Backstroke LCM Male',
#     'Women 100 Butterfly LCM Female',   'Women 100 Backstroke LCM Female',
#  'Women 100 Breaststroke LCM Female',        'Men 200 Butterfly LCM Male',
#     'Women 200 Freestyle LCM Female',       'Men 200 Backstroke LCM Male',
#            'Men 200 Medley LCM Male',   'Women 200 Backstroke LCM Female',
#     'Women 200 Butterfly LCM Female', 'Women 200 Breaststroke LCM Female',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',    'Women 800 Freestyle LCM Female']
# Length: 16, dtype: string
#
#  US Olympic Team Trials - Swimming
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#        'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',     'Men 100 Breaststroke LCM Male',
#  'Women 100 Breaststroke LCM Female',       'Men 200 Backstroke LCM Male',
#     'Women 200 Freestyle LCM Female',           'Men 200 Medley LCM Male',
#    'Women 200 Backstroke LCM Female',     'Men 200 Breaststroke LCM Male',
#        'Women 200 Medley LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male']
# Length: 19, dtype: string
#
#  US Olympic Team Trials - Wave II
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',        'Men 100 Butterfly LCM Male',
#        'Men 100 Backstroke LCM Male',    'Women 100 Freestyle LCM Female',
#     'Women 100 Butterfly LCM Female',   'Women 100 Backstroke LCM Female',
#      'Men 100 Breaststroke LCM Male', 'Women 100 Breaststroke LCM Female',
#         'Men 200 Freestyle LCM Male',       'Men 200 Backstroke LCM Male',
#     'Women 200 Freestyle LCM Female',           'Men 200 Medley LCM Male',
#    'Women 200 Backstroke LCM Female',    'Women 200 Butterfly LCM Female',
#      'Men 200 Breaststroke LCM Male',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',        'Men 400 Freestyle LCM Male',
#     'Women 400 Freestyle LCM Female',           'Men 400 Medley LCM Male',
#        'Women 400 Medley LCM Female',    'Women 800 Freestyle LCM Female',
#        'Men 1500 Freestyle LCM Male',   'Women 1500 Freestyle LCM Female']
# Length: 24, dtype: string
#
#  US Open 2009
#  <StringArray>
# ['Women 100 Breaststroke LCM Female']
# Length: 1, dtype: string
#
#  US Santa Clara International 2012
#  <StringArray>
# ['Men 200 Butterfly LCM Male']
# Length: 1, dtype: string
#
#  US Spring National Championships (50m)
#  <StringArray>
# ['Women 800 Freestyle LCM Female', 'Women 1500 Freestyle LCM Female']
# Length: 2, dtype: string
#
#  US Winter National Championships (50m)
#  <StringArray>
# ['Women 100 Breaststroke LCM Female',   'Women 200 Backstroke LCM Female',
#        'Women 200 Medley LCM Female', 'Women 200 Breaststroke LCM Female',
#     'Women 400 Freestyle LCM Female']
# Length: 5, dtype: string
#
#  USA Olympic Team Trials
#  <StringArray>
# [    'Men 200 Backstroke LCM Male',         'Men 200 Medley LCM Male',
#  'Women 200 Backstroke LCM Female',         'Men 400 Medley LCM Male',
#      'Women 400 Medley LCM Female']
# Length: 5, dtype: string
#
#  USA Olympic Trials 2004
#  <StringArray>
# [       'Men 100 Butterfly LCM Male',       'Men 200 Backstroke LCM Male',
#  'Women 200 Breaststroke LCM Female',           'Men 400 Medley LCM Male']
# Length: 4, dtype: string
#
#  USA Winter National Championships (50m)
#  <StringArray>
# [       'Men 100 Freestyle LCM Male',    'Women 100 Freestyle LCM Female',
#    'Women 100 Backstroke LCM Female', 'Women 100 Breaststroke LCM Female',
#     'Women 200 Freestyle LCM Female',       'Women 200 Medley LCM Female',
#  'Women 200 Breaststroke LCM Female',    'Women 400 Freestyle LCM Female',
#         'Men 800 Freestyle LCM Male',    'Women 800 Freestyle LCM Female',
#    'Women 1500 Freestyle LCM Female']
# Length: 11, dtype: string
#
#  Ukrainian National Cup
#  <StringArray>
# ['Men 100 Breaststroke LCM Male']
# Length: 1, dtype: string
#
#  Victorian Open Championships 2016
#  <StringArray>
# [    'Men 100 Backstroke LCM Male',     'Men 200 Backstroke LCM Male',
#  'Women 200 Backstroke LCM Female']
# Length: 3, dtype: string
#
#  Victorian Open Championships 2022
#  <StringArray>
# ['Women 100 Backstroke LCM Female', 'Women 200 Backstroke LCM Female']
# Length: 2, dtype: string
#
#  Youth Olympic Games Buenos Aires 2018
#  <StringArray>
# ['Men 100 Butterfly LCM Male']
# Length: 1, dtype: string
#
#  Youth Olympic Games Nanjing 2014
#  <StringArray>
# [   'Women 100 Freestyle LCM Female', 'Women 100 Breaststroke LCM Female',
#     'Women 200 Butterfly LCM Female']
# Length: 3, dtype: string

# %% [markdown]
# ## Take one of the groupings and design a collection around it.

# %%
for i in sorted(df.Athlete_Full_Name.unique()):
     if len(df[df.Athlete_Full_Name==i].Athlete_birth_date.unique())!=1:
        print(i,"Not 1 birth date")
     if len(df[df.Athlete_Full_Name==i].Team_Code.unique())!=1:
        print(i,"Not 1 Team Code", len(df[df.Athlete_Full_Name==i].Team_Code.unique()))
     if len(df[df.Athlete_Full_Name==i].Gender.unique())!=1:
        print(i,"Not 1 Gender")
# Out:
# CHIKUNOVA, Evgeniia Not 1 Team Code 2
# CHUPKOV, Anton Not 1 Team Code 2
# EFIMOVA, Yuliya Not 1 Team Code 2
# GANDY, Ellen Not 1 Team Code 2
# KIRPICHNIKOVA, Anastasiia Not 1 Team Code 2
# KOLESNIKOV, Kliment Not 1 Team Code 2
# MALYUTIN, Martin Not 1 Team Code 2
# MINAKOV, Andrei Not 1 Team Code 2
# RYLOV, Evgeny Not 1 Team Code 2

# %% [markdown]
# ### Design
#
# We will have a 1:few between Athlete and Swim.
# The columns are 'Event_Name', 'Swim_time', 'Swim_date', 'Event_description', 'Team_Code', 'Team_Name', 'Athlete_Full_Name', 'Gender', 'Athlete_birth_date', 'Rank_Order', 'City', 'Country_Code', 'Duration_(hh:mm:ss:ff)'
#
# If we design one document per athlete, let's take the unique athlete information from:
#     'Athlete_Full_Name', 'Gender', 'Athlete_birth_date'
#
# We  can then have an embedded array of the athlete's swims, from:
# 'Event_Name', 'Event_description', 'Swim_time', 'Swim_date', 'Team_Code','Team_Name' 'Rank_Order', 'City', 'Country_Code', 'Duration_(hh:mm:ss:ff)'

# %% [markdown]
# #### Json serializable data can't be dates or times.  Let's use the string version of our time.

# %%
print('Event_Name', df.Event_Name.isnull().sum())
print('Event_description', df.Event_description.isnull().sum())
print('Swim_date', df.Swim_date.isnull().sum())
print('Rank_Order', df.Rank_Order.isnull().sum())
print('City', df.City.isnull().sum())
print('Duration', df.Duration.isnull().sum())
# Out:
# Event_Name 0
# Event_description 0
# Swim_date 0
# Rank_Order 0
# City 2
# Duration 0

# %%
df[df.City.isnull()]
# Out:
#            Event_Name   Swim_date               Event_description Team_Code  \
# 982   2012 AUS Invite  2013-12-16  Women 100 Butterfly LCM Female       AUS
# 4257     Italy Invite  2016-04-30     Women 400 Medley LCM Female       HUN
#
#       Team_Name Athlete_Full_Name Gender Athlete_birth_date  Rank_Order  City  \
# 982   Australia      GANDY, Ellen      F         1991-08-15         182  <NA>
# 4257    Hungary   HOSSZU, Katinka      F         1989-05-03          58  <NA>
#
#      Country_Code    Duration
# 982           AUS   0:0:56:94
# 4257          ITA  0:04:32:68

# %%
df["City"].fillna("Not Specified", inplace = True)

# %%
df[['Event_Name', 
                                                                  'Event_description', 
                                                                  'Swim_date', 
                                                                  'Rank_Order', 
                                                                  'City', 
                                                                  'Country_Code', 
                                                                  'Duration']].isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Extracting the documents

# %% [markdown]
# #### Set up an athlete's dataframe

# %%
adf = df[['Athlete_Full_Name', 'Gender', 'Athlete_birth_date']].drop_duplicates()

# %%
print(adf.Athlete_Full_Name)
# Out:
# 0                   POPOVICI, David
# 1                CIELO FILHO, Cesar
# 2                    BERNARD, Alain
# 3                   DRESSEL, Caeleb
# 6                   MCEVOY, Cameron
#                    ...
# 5184            NORDIN, Emma Ayasha
# 5187                GORMAN, Melissa
# 5191                    SHAO, Yiwen
# 5196    MIHALYVARI-FARKAS, Viktoria
# 5199                MURPHY, Grainne
# Name: Athlete_Full_Name, Length: 716, dtype: string

# %%
adf.describe(include='all')
# Out:
#        Athlete_Full_Name Gender Athlete_birth_date
# count                716    716                716
# unique               716      2                683
# top      POPOVICI, David      F         1992-05-20
# freq                   1    409                  3

# %%
adf.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Connect to MongoDB and make a collection

# %%
# #### Set up the database and collection you will use.
uri = 'mongodb://admin:Sp00ky!@localhost:27017/?AuthSource=admin'
client = MongoClient(uri)

mydb = client["Swimming"]
mycol = mydb["Athlete"]
mycol.drop()

#

# %% [markdown]
# #### Loop through each athlete to create a document

# %%
for row in adf.itertuples():
    print(row.Athlete_Full_Name, type(row))
    theirswims = df[df.Athlete_Full_Name==row.Athlete_Full_Name][['Event_Name', 
                                                                  'Event_description', 
                                                                  'Swim_date', 
                                                                  'Team_Code',
                                                                  'Team_Name',
                                                                  'Rank_Order', 
                                                                  'City', 
                                                                  'Country_Code', 
                                                                  'Duration']]
    entries = json.dumps({"Name": row.Athlete_Full_Name,
                          "Birth_Date": row.Athlete_birth_date,
                          "Gender":row.Gender,
                          "Swims": theirswims.to_dict('records')
                             })
    x = mycol.insert_one(json.loads(entries))
# Out:
# POPOVICI, David <class 'pandas.core.frame.Pandas'>
# CIELO FILHO, Cesar <class 'pandas.core.frame.Pandas'>
# BERNARD, Alain <class 'pandas.core.frame.Pandas'>
# DRESSEL, Caeleb <class 'pandas.core.frame.Pandas'>
# MCEVOY, Cameron <class 'pandas.core.frame.Pandas'>
# SULLIVAN, Eamon <class 'pandas.core.frame.Pandas'>
# CHALMERS, Kyle <class 'pandas.core.frame.Pandas'>
# MAGNUSSEN, James <class 'pandas.core.frame.Pandas'>
# KOLESNIKOV, Kliment <class 'pandas.core.frame.Pandas'>
# BOUSQUET, Frederick <class 'pandas.core.frame.Pandas'>
# HAYDEN, Brent <class 'pandas.core.frame.Pandas'>
# WALTERS, David <class 'pandas.core.frame.Pandas'>
# NYSTRAND, Stefan <class 'pandas.core.frame.Pandas'>
# HELD, Ryan <class 'pandas.core.frame.Pandas'>
# GRINEV, Vladislav <class 'pandas.core.frame.Pandas'>
# MIRESSI, Alessandro <class 'pandas.core.frame.Pandas'>
# MILAK, Kristof <class 'pandas.core.frame.Pandas'>
# PHELPS, Michael <class 'pandas.core.frame.Pandas'>
# GROUSSET, Maxime <class 'pandas.core.frame.Pandas'>
# ADRIAN, Nathan <class 'pandas.core.frame.Pandas'>
# LIENDO EDWARDS, Joshua <class 'pandas.core.frame.Pandas'>
# HWANG, Sunwoo <class 'pandas.core.frame.Pandas'>
# MINAKOV, Andrei <class 'pandas.core.frame.Pandas'>
# ROONEY, Maxime <class 'pandas.core.frame.Pandas'>
# MOROZOV, Vladimir <class 'pandas.core.frame.Pandas'>
# BURRAS, Lewis Edward <class 'pandas.core.frame.Pandas'>
# ROBERTS, James <class 'pandas.core.frame.Pandas'>
# PAN, Zhanle <class 'pandas.core.frame.Pandas'>
# METELLA, Mehdy <class 'pandas.core.frame.Pandas'>
# NING, Zetao <class 'pandas.core.frame.Pandas'>
# LEZAK, Jason <class 'pandas.core.frame.Pandas'>
# CHIERIGHINI, Marcelo <class 'pandas.core.frame.Pandas'>
# VAN DEN HOOGENBAND, Pieter <class 'pandas.core.frame.Pandas'>
# NEMETH, Nandor <class 'pandas.core.frame.Pandas'>
# APPLE, Zach <class 'pandas.core.frame.Pandas'>
# CECCON, Thomas <class 'pandas.core.frame.Pandas'>
# GILOT, Fabien <class 'pandas.core.frame.Pandas'>
# LEVEAUX, Amaury <class 'pandas.core.frame.Pandas'>
# OLIVEIRA, Nicolas <class 'pandas.core.frame.Pandas'>
# FERNS, Lyndon <class 'pandas.core.frame.Pandas'>
# TIMMERS, Pieter <class 'pandas.core.frame.Pandas'>
# FEIGEN, Jimmy <class 'pandas.core.frame.Pandas'>
# DEAN, Tom <class 'pandas.core.frame.Pandas'>
# AGNEL, Yannick <class 'pandas.core.frame.Pandas'>
# SCOTT, Duncan <class 'pandas.core.frame.Pandas'>
# PIERONI, Blake <class 'pandas.core.frame.Pandas'>
# NAKAMURA, Katsumi <class 'pandas.core.frame.Pandas'>
# JACKSON, Tate <class 'pandas.core.frame.Pandas'>
# CONDORELLI, Santo <class 'pandas.core.frame.Pandas'>
# CAVIC, Milorad <class 'pandas.core.frame.Pandas'>
# SCHOOLING, Joseph <class 'pandas.core.frame.Pandas'>
# CASAS, Shaine <class 'pandas.core.frame.Pandas'>
# CROCKER, Ian <class 'pandas.core.frame.Pandas'>
# MUNOZ, Rafael <class 'pandas.core.frame.Pandas'>
# TEMPLE, Matthew <class 'pandas.core.frame.Pandas'>
# LE CLOS, Chad <class 'pandas.core.frame.Pandas'>
# CODIA, Piero <class 'pandas.core.frame.Pandas'>
# SUBIRATS, Albert <class 'pandas.core.frame.Pandas'>
# GUY, James <class 'pandas.core.frame.Pandas'>
# PONTI, Noe <class 'pandas.core.frame.Pandas'>
# DUNFORD, Jason <class 'pandas.core.frame.Pandas'>
# ANDREW, Michael <class 'pandas.core.frame.Pandas'>
# MIZUNUMA, Naoki <class 'pandas.core.frame.Pandas'>
# LAUTERSTEIN, Andrew <class 'pandas.core.frame.Pandas'>
# CSEH, Laszlo <class 'pandas.core.frame.Pandas'>
# MCGILL, Tyler <class 'pandas.core.frame.Pandas'>
# MAJERSKI, Jakub <class 'pandas.core.frame.Pandas'>
# MILADINOV, Josif <class 'pandas.core.frame.Pandas'>
# LI, Zhuhao <class 'pandas.core.frame.Pandas'>
# KAWAMOTO, Takeshi <class 'pandas.core.frame.Pandas'>
# CONGER, Jack <class 'pandas.core.frame.Pandas'>
# IRVINE, Grant <class 'pandas.core.frame.Pandas'>
# KAWAMOTO, Kouhei <class 'pandas.core.frame.Pandas'>
# MANGABEIRA, Gabriel <class 'pandas.core.frame.Pandas'>
# SHIELDS, Tom <class 'pandas.core.frame.Pandas'>
# MARTINEZ, Luis Carlos <class 'pandas.core.frame.Pandas'>
# JULIAN, Trenton <class 'pandas.core.frame.Pandas'>
# SERDINOV, Andriy <class 'pandas.core.frame.Pandas'>
# ISHIKAWA, Shinnosuke <class 'pandas.core.frame.Pandas'>
# TANAKA, Daiki <class 'pandas.core.frame.Pandas'>
# CZERNIAK, Konrad <class 'pandas.core.frame.Pandas'>
# KUIMOV, Egor <class 'pandas.core.frame.Pandas'>
# BUCHER, Simon <class 'pandas.core.frame.Pandas'>
# MATSUMOTO, Katsuhiro <class 'pandas.core.frame.Pandas'>
# DEIBLER, Steffen <class 'pandas.core.frame.Pandas'>
# SJOESTROEM, Sarah <class 'pandas.core.frame.Pandas'>
# MURPHY, Ryan <class 'pandas.core.frame.Pandas'>
# XU, Jiayu <class 'pandas.core.frame.Pandas'>
# PEIRSOL, Aaron <class 'pandas.core.frame.Pandas'>
# MCKEON, Emma <class 'pandas.core.frame.Pandas'>
# ARMSTRONG, Hunter <class 'pandas.core.frame.Pandas'>
# RYLOV, Evgeny <class 'pandas.core.frame.Pandas'>
# CAMPBELL, Cate <class 'pandas.core.frame.Pandas'>
# MANUEL, Simone <class 'pandas.core.frame.Pandas'>
# STEFFEN, Britta <class 'pandas.core.frame.Pandas'>
# GREVERS, Matt <class 'pandas.core.frame.Pandas'>
# CHRISTOU, Apostolos <class 'pandas.core.frame.Pandas'>
# LARKIN, Mitchell <class 'pandas.core.frame.Pandas'>
# LACOURT, Camille <class 'pandas.core.frame.Pandas'>
# PLUMMER, David <class 'pandas.core.frame.Pandas'>
# IRIE, Ryosuke <class 'pandas.core.frame.Pandas'>
# KOGA, Junya <class 'pandas.core.frame.Pandas'>
# MEEUW, Helge <class 'pandas.core.frame.Pandas'>
# HAUGHEY, Siobhan Bernadette <class 'pandas.core.frame.Pandas'>
# CAMPBELL, Bronte <class 'pandas.core.frame.Pandas'>
# WILDEBOER FABER, Aschwin <class 'pandas.core.frame.Pandas'>
# O'CALLAGHAN, Mollie <class 'pandas.core.frame.Pandas'>
# NDOYE-BROUARD, Yohann <class 'pandas.core.frame.Pandas'>
# VYATCHANIN, Arkady <class 'pandas.core.frame.Pandas'>
# MASIUK, Ksawery <class 'pandas.core.frame.Pandas'>
# OLEKSIAK, Penny <class 'pandas.core.frame.Pandas'>
# COMERFORD, Mallory <class 'pandas.core.frame.Pandas'>
# JACK, Shayna <class 'pandas.core.frame.Pandas'>
# LENTON, Libby <class 'pandas.core.frame.Pandas'>
# BLUME, Pernille <class 'pandas.core.frame.Pandas'>
# HEEMSKERK, Femke <class 'pandas.core.frame.Pandas'>
# RUCK, Taylor <class 'pandas.core.frame.Pandas'>
# RESS, Justin <class 'pandas.core.frame.Pandas'>
# TANCOCK, Liam <class 'pandas.core.frame.Pandas'>
# BONNET, Charlotte <class 'pandas.core.frame.Pandas'>
# HOPKIN, Anna <class 'pandas.core.frame.Pandas'>
# KROMOWIDJOJO, Ranomi <class 'pandas.core.frame.Pandas'>
# STRAVIUS, Jeremy <class 'pandas.core.frame.Pandas'>
# WILSON, Madison <class 'pandas.core.frame.Pandas'>
# GONZALEZ, Hugo <class 'pandas.core.frame.Pandas'>
# HAGINO, Kosuke <class 'pandas.core.frame.Pandas'>
# IKEE, Rikako <class 'pandas.core.frame.Pandas'>
# TOMAC, Mewen <class 'pandas.core.frame.Pandas'>
# THOMAN, Nick <class 'pandas.core.frame.Pandas'>
# MEFFORD, Bryce <class 'pandas.core.frame.Pandas'>
# HALSALL, Fran <class 'pandas.core.frame.Pandas'>
# ZHANG, Yufei <class 'pandas.core.frame.Pandas'>
# HUSKE, Torri <class 'pandas.core.frame.Pandas'>
# HARRIS, Meg <class 'pandas.core.frame.Pandas'>
# WEITZEIL, Abbey <class 'pandas.core.frame.Pandas'>
# YANG, Junxuan <class 'pandas.core.frame.Pandas'>
# WEIR, Amanda <class 'pandas.core.frame.Pandas'>
# COLEMAN, Michelle <class 'pandas.core.frame.Pandas'>
# WATTEL, Marie <class 'pandas.core.frame.Pandas'>
# SANCHEZ, Kayla <class 'pandas.core.frame.Pandas'>
# PANG, Jiaying <class 'pandas.core.frame.Pandas'>
# PELLEGRINI, Federica <class 'pandas.core.frame.Pandas'>
# STEENBERGEN, Marrit <class 'pandas.core.frame.Pandas'>
# TANG, Yi <class 'pandas.core.frame.Pandas'>
# VOLLMER, Dana <class 'pandas.core.frame.Pandas'>
# ANDERSON, Freya <class 'pandas.core.frame.Pandas'>
# OTTESEN, Jeanette <class 'pandas.core.frame.Pandas'>
# CHENG, Yujie <class 'pandas.core.frame.Pandas'>
# FRANKLIN, Missy <class 'pandas.core.frame.Pandas'>
# HERASIMENIA, Aliaksandra <class 'pandas.core.frame.Pandas'>
# WRIGHT, Melanie <class 'pandas.core.frame.Pandas'>
# COUGHLIN, Natalie <class 'pandas.core.frame.Pandas'>
# GASTALDELLO, Beryl <class 'pandas.core.frame.Pandas'>
# ZHU, Menghui <class 'pandas.core.frame.Pandas'>
# BROWN, Erika <class 'pandas.core.frame.Pandas'>
# GEER, Margo <class 'pandas.core.frame.Pandas'>
# KAMENEVA, Mariia <class 'pandas.core.frame.Pandas'>
# MUFFAT, Camille <class 'pandas.core.frame.Pandas'>
# HENRY, Jodie <class 'pandas.core.frame.Pandas'>
# HINDS, Natalie <class 'pandas.core.frame.Pandas'>
# BRO, Signe <class 'pandas.core.frame.Pandas'>
# ELMSLIE, Brittany <class 'pandas.core.frame.Pandas'>
# SMOLIGA, Olivia <class 'pandas.core.frame.Pandas'>
# CURZAN, Claire <class 'pandas.core.frame.Pandas'>
# ALSHAMMAR, Therese <class 'pandas.core.frame.Pandas'>
# NEAL, Lia <class 'pandas.core.frame.Pandas'>
# SEPPALA, Hanna-Maria <class 'pandas.core.frame.Pandas'>
# DEKKER, Inge <class 'pandas.core.frame.Pandas'>
# HOSSZU, Katinka <class 'pandas.core.frame.Pandas'>
# SCHLANGER, Melanie <class 'pandas.core.frame.Pandas'>
# VELDHUIS, Magdalena <class 'pandas.core.frame.Pandas'>
# TITMUS, Ariarne <class 'pandas.core.frame.Pandas'>
# SEEMANOVA, Barbora <class 'pandas.core.frame.Pandas'>
# VANDERPOOL-WALLACE, Arianna <class 'pandas.core.frame.Pandas'>
# WALSH, Gretchen <class 'pandas.core.frame.Pandas'>
# VERRASZTO, Evelin <class 'pandas.core.frame.Pandas'>
# LEDECKY, Katie <class 'pandas.core.frame.Pandas'>
# SCHREIBER, Daniela <class 'pandas.core.frame.Pandas'>
# DELOOF, Catie <class 'pandas.core.frame.Pandas'>
# MAINVILLE, Sandrine <class 'pandas.core.frame.Pandas'>
# DE BRUIJN, Inge <class 'pandas.core.frame.Pandas'>
# MACK, Linnea <class 'pandas.core.frame.Pandas'>
# COUTTS, Alicia <class 'pandas.core.frame.Pandas'>
# SCHMITT, Allison <class 'pandas.core.frame.Pandas'>
# THROSSELL, Brianna <class 'pandas.core.frame.Pandas'>
# O'CONNOR, Siobhan <class 'pandas.core.frame.Pandas'>
# VAN LANDEGHEM, Chantal <class 'pandas.core.frame.Pandas'>
# VREELAND, Shannon <class 'pandas.core.frame.Pandas'>
# WU, Qingfeng <class 'pandas.core.frame.Pandas'>
# SHEN, Duo <class 'pandas.core.frame.Pandas'>
# ZHU, Yingwen <class 'pandas.core.frame.Pandas'>
# HARDY, Jessica <class 'pandas.core.frame.Pandas'>
# DAHLIA, Kelsi <class 'pandas.core.frame.Pandas'>
# HOPE, Lucy <class 'pandas.core.frame.Pandas'>
# QIU, Yuhan <class 'pandas.core.frame.Pandas'>
# ROMANO, Megan <class 'pandas.core.frame.Pandas'>
# PALMER, Hayley <class 'pandas.core.frame.Pandas'>
# METELLA, Malia <class 'pandas.core.frame.Pandas'>
# SEEBOHM, Emily <class 'pandas.core.frame.Pandas'>
# UCHIDA, Miki <class 'pandas.core.frame.Pandas'>
# ANDRUSENKO, Veronika <class 'pandas.core.frame.Pandas'>
# ZEVNIK, Alexia <class 'pandas.core.frame.Pandas'>
# BRUHN, Annika <class 'pandas.core.frame.Pandas'>
# LI, Zhesi <class 'pandas.core.frame.Pandas'>
# COUDERC, Celine <class 'pandas.core.frame.Pandas'>
# DOUGLASS, Kate <class 'pandas.core.frame.Pandas'>
# AI, Yanhan <class 'pandas.core.frame.Pandas'>
# UEDA, Haruka <class 'pandas.core.frame.Pandas'>
# SMITH, Amy <class 'pandas.core.frame.Pandas'>
# LE, Jingyi <class 'pandas.core.frame.Pandas'>
# SURKOVA, Arina <class 'pandas.core.frame.Pandas'>
# MACNEIL, Margaret <class 'pandas.core.frame.Pandas'>
# KUKLA, Yolane <class 'pandas.core.frame.Pandas'>
# OLIVEIRA, Larissa <class 'pandas.core.frame.Pandas'>
# BUSCH, Kim <class 'pandas.core.frame.Pandas'>
# MUREZ, Andrea <class 'pandas.core.frame.Pandas'>
# LILLHAGE, Josefin <class 'pandas.core.frame.Pandas'>
# MORNINGSTAR, Erica <class 'pandas.core.frame.Pandas'>
# BALDUCCINI, Stephanie <class 'pandas.core.frame.Pandas'>
# IGARASHI, Chihiro <class 'pandas.core.frame.Pandas'>
# NGAWATI, Kotuku <class 'pandas.core.frame.Pandas'>
# DI PIETRO, Silvia <class 'pandas.core.frame.Pandas'>
# TARANTINO, Chiara <class 'pandas.core.frame.Pandas'>
# JOYCE, Kara Lynn <class 'pandas.core.frame.Pandas'>
# MC LAUGHLIN, Katie <class 'pandas.core.frame.Pandas'>
# EDWARDS, Crystal <class 'pandas.core.frame.Pandas'>
# TORO, Michelle <class 'pandas.core.frame.Pandas'>
# LOVTCOVA, Natalia <class 'pandas.core.frame.Pandas'>
# LU, Bin <class 'pandas.core.frame.Pandas'>
# OMOTO, Rika <class 'pandas.core.frame.Pandas'>
# WILKINSON, Julia <class 'pandas.core.frame.Pandas'>
# NEALE, Leah <class 'pandas.core.frame.Pandas'>
# RUSSELL, Sinead <class 'pandas.core.frame.Pandas'>
# GROVES, Madeline <class 'pandas.core.frame.Pandas'>
# KENNEDY, Madison <class 'pandas.core.frame.Pandas'>
# HUNTER, Sally <class 'pandas.core.frame.Pandas'>
# GUEHRER, Marieke <class 'pandas.core.frame.Pandas'>
# WASICK, Katarzyna <class 'pandas.core.frame.Pandas'>
# GALLAGHER, Erin <class 'pandas.core.frame.Pandas'>
# ANTONIOU, Kalia <class 'pandas.core.frame.Pandas'>
# SMIT, Julia <class 'pandas.core.frame.Pandas'>
# MEDEIROS, Etiene <class 'pandas.core.frame.Pandas'>
# HANSSON, Louise <class 'pandas.core.frame.Pandas'>
# SHIRAI, Rio <class 'pandas.core.frame.Pandas'>
# POON, Victoria <class 'pandas.core.frame.Pandas'>
# APOSTALON, Anika <class 'pandas.core.frame.Pandas'>
# SEGEL, Janja <class 'pandas.core.frame.Pandas'>
# MCKEOWN, Kaylee <class 'pandas.core.frame.Pandas'>
# CASEY, Hannah <class 'pandas.core.frame.Pandas'>
# FERRAIOLI, Erika <class 'pandas.core.frame.Pandas'>
# O'LEARY, Mia Patricia <class 'pandas.core.frame.Pandas'>
# MILLS, Alice <class 'pandas.core.frame.Pandas'>
# SAKAI, Natsumi <class 'pandas.core.frame.Pandas'>
# MUNOZ DEL CAMPO, Lidon <class 'pandas.core.frame.Pandas'>
# SHKURDAI, Anastasiya <class 'pandas.core.frame.Pandas'>
# MATSUMOTO, Yayoi <class 'pandas.core.frame.Pandas'>
# GORBENKO, Anastasia <class 'pandas.core.frame.Pandas'>
# WILSON, Hannah <class 'pandas.core.frame.Pandas'>
# ALBIERO, Gabi <class 'pandas.core.frame.Pandas'>
# BARRATT, Bronte <class 'pandas.core.frame.Pandas'>
# VAN ALMSICK, Franziska <class 'pandas.core.frame.Pandas'>
# THOMPSON, Jenny <class 'pandas.core.frame.Pandas'>
# SHAN, Ying <class 'pandas.core.frame.Pandas'>
# NELSON, Beata <class 'pandas.core.frame.Pandas'>
# SATO, Aya <class 'pandas.core.frame.Pandas'>
# DE LOOF, Gabby <class 'pandas.core.frame.Pandas'>
# KLEVANOVICH, Elizaveta <class 'pandas.core.frame.Pandas'>
# LAO, Lihui <class 'pandas.core.frame.Pandas'>
# TORRES, Dara <class 'pandas.core.frame.Pandas'>
# WEBB, Abbey <class 'pandas.core.frame.Pandas'>
# SMITH, Rebecca <class 'pandas.core.frame.Pandas'>
# MEYNEN, Julie <class 'pandas.core.frame.Pandas'>
# BELIAKOVA, Viktoriia <class 'pandas.core.frame.Pandas'>
# CINI, Mathilde <class 'pandas.core.frame.Pandas'>
# VAN DER MEER, Maud <class 'pandas.core.frame.Pandas'>
# KLEPIKOVA, Daria <class 'pandas.core.frame.Pandas'>
# BOUSQUIN, Lena <class 'pandas.core.frame.Pandas'>
# AOKI, Tomomi <class 'pandas.core.frame.Pandas'>
# WILLIAMS, Michelle <class 'pandas.core.frame.Pandas'>
# OPENYSHEVA, Arina <class 'pandas.core.frame.Pandas'>
# MORAVCOVA, Martina <class 'pandas.core.frame.Pandas'>
# KLANCAR, Neza <class 'pandas.core.frame.Pandas'>
# BURCHILL, Veronica <class 'pandas.core.frame.Pandas'>
# NIELSEN, Mie Oe <class 'pandas.core.frame.Pandas'>
# TOUSSAINT, Kira <class 'pandas.core.frame.Pandas'>
# FABRE, Margaux <class 'pandas.core.frame.Pandas'>
# PRINSLOO, Karin <class 'pandas.core.frame.Pandas'>
# NIANGKOUARA, Nery Mantey <class 'pandas.core.frame.Pandas'>
# JAKABOS, Zsuzsanna <class 'pandas.core.frame.Pandas'>
# SAVARD, Katerine <class 'pandas.core.frame.Pandas'>
# ZHUANG, Yong <class 'pandas.core.frame.Pandas'>
# KENDALL, Amanda <class 'pandas.core.frame.Pandas'>
# KOST, Nina <class 'pandas.core.frame.Pandas'>
# WANG, Jingzhuo <class 'pandas.core.frame.Pandas'>
# FREITAG, Meike <class 'pandas.core.frame.Pandas'>
# DALLMANN, Petra <class 'pandas.core.frame.Pandas'>
# PERKINS, Alexandria <class 'pandas.core.frame.Pandas'>
# UGOLKOVA, Maria <class 'pandas.core.frame.Pandas'>
# SUN, Meichen <class 'pandas.core.frame.Pandas'>
# USTINOVA, Daria S <class 'pandas.core.frame.Pandas'>
# FULMER, Amy <class 'pandas.core.frame.Pandas'>
# NORDMANN, Lillie <class 'pandas.core.frame.Pandas'>
# GIELE, Tessa <class 'pandas.core.frame.Pandas'>
# BALDWIN, Caroline Grace <class 'pandas.core.frame.Pandas'>
# FORRESTER, Jenna <class 'pandas.core.frame.Pandas'>
# WU, Yue <class 'pandas.core.frame.Pandas'>
# STEIGER, Jessica <class 'pandas.core.frame.Pandas'>
# MARTIN, Anouchka <class 'pandas.core.frame.Pandas'>
# MATSUO, Ami <class 'pandas.core.frame.Pandas'>
# SCHREUDER, Hinkelien <class 'pandas.core.frame.Pandas'>
# LIU, Zige <class 'pandas.core.frame.Pandas'>
# SCHIPPER, Jess <class 'pandas.core.frame.Pandas'>
# CHEN, Xinyi <class 'pandas.core.frame.Pandas'>
# LU, Ying <class 'pandas.core.frame.Pandas'>
# JIAO, Liuyang <class 'pandas.core.frame.Pandas'>
# PEATY, Adam <class 'pandas.core.frame.Pandas'>
# MONGEL, Aurore <class 'pandas.core.frame.Pandas'>
# GANDY, Ellen <class 'pandas.core.frame.Pandas'>
# SILVA, Gabriella <class 'pandas.core.frame.Pandas'>
# SNILDAL, Ingvild Nicoline <class 'pandas.core.frame.Pandas'>
# SMITH, Regan <class 'pandas.core.frame.Pandas'>
# MASSE, Kylie <class 'pandas.core.frame.Pandas'>
# KAMMINGA, Arno <class 'pandas.core.frame.Pandas'>
# BAKER, Kathleen <class 'pandas.core.frame.Pandas'>
# DAWSON, Kathleen <class 'pandas.core.frame.Pandas'>
# SPOFFORTH, Gemma <class 'pandas.core.frame.Pandas'>
# ZUEVA, Anastasia <class 'pandas.core.frame.Pandas'>
# MARTINENGHI, Nicolo <class 'pandas.core.frame.Pandas'>
# SHYMANOVICH, Ilya <class 'pandas.core.frame.Pandas'>
# FINK, Nic <class 'pandas.core.frame.Pandas'>
# WHITE, Rhyan <class 'pandas.core.frame.Pandas'>
# WILBY, James <class 'pandas.core.frame.Pandas'>
# VAN DER BURGH, Cameron <class 'pandas.core.frame.Pandas'>
# RICKARD, Brenton <class 'pandas.core.frame.Pandas'>
# ATHERTON, Minna <class 'pandas.core.frame.Pandas'>
# BERKOFF, Katharine <class 'pandas.core.frame.Pandas'>
# BACON, Phoebe <class 'pandas.core.frame.Pandas'>
# YAN, Zibei <class 'pandas.core.frame.Pandas'>
# CORDES, Kevin <class 'pandas.core.frame.Pandas'>
# DUBOSCQ, Hugues <class 'pandas.core.frame.Pandas'>
# BORYSIK, Igor <class 'pandas.core.frame.Pandas'>
# TERAKAWA, Aya <class 'pandas.core.frame.Pandas'>
# DALE OEN, Alexander <class 'pandas.core.frame.Pandas'>
# FU, Yuanhui <class 'pandas.core.frame.Pandas'>
# WILSON, Andrew <class 'pandas.core.frame.Pandas'>
# COVENTRY, Kirsty <class 'pandas.core.frame.Pandas'>
# KOSEKI, Yasuhiro <class 'pandas.core.frame.Pandas'>
# SPRENGER, Christian <class 'pandas.core.frame.Pandas'>
# FESIKOVA, Anastasiia <class 'pandas.core.frame.Pandas'>
# CHUPKOV, Anton <class 'pandas.core.frame.Pandas'>
# SAKCI, Huseyin <class 'pandas.core.frame.Pandas'>
# MILLER, Cody <class 'pandas.core.frame.Pandas'>
# KITAJIMA, Kosuke <class 'pandas.core.frame.Pandas'>
# SCHWINGENSCHLOGL, Fabian <class 'pandas.core.frame.Pandas'>
# TITENIS, Giedrius <class 'pandas.core.frame.Pandas'>
# SHANTEAU, Eric <class 'pandas.core.frame.Pandas'>
# POGGIO, Federico <class 'pandas.core.frame.Pandas'>
# FRANCA SILVA, Felipe <class 'pandas.core.frame.Pandas'>
# KING, Lilly <class 'pandas.core.frame.Pandas'>
# MEILUTYTE, Ruta <class 'pandas.core.frame.Pandas'>
# EFIMOVA, Yuliya <class 'pandas.core.frame.Pandas'>
# SCHOENMAKER, Tatjana <class 'pandas.core.frame.Pandas'>
# SONI, Rebecca <class 'pandas.core.frame.Pandas'>
# JACOBY, Lydia <class 'pandas.core.frame.Pandas'>
# MEILI, Katie <class 'pandas.core.frame.Pandas'>
# JONES, Leisel <class 'pandas.core.frame.Pandas'>
# AOKI, Reona <class 'pandas.core.frame.Pandas'>
# JI, Liping <class 'pandas.core.frame.Pandas'>
# LAZOR, Annie <class 'pandas.core.frame.Pandas'>
# VAN NIEKERK, Lara <class 'pandas.core.frame.Pandas'>
# ELENDT, Anna <class 'pandas.core.frame.Pandas'>
# YU, Jingyao <class 'pandas.core.frame.Pandas'>
# HANSSON, Sophie <class 'pandas.core.frame.Pandas'>
# CASTIGLIONI, Arianna <class 'pandas.core.frame.Pandas'>
# PILATO, Benedetta <class 'pandas.core.frame.Pandas'>
# PIERSE, Annamay <class 'pandas.core.frame.Pandas'>
# GALAT, Bethany <class 'pandas.core.frame.Pandas'>
# CARLSON, Kasey <class 'pandas.core.frame.Pandas'>
# HANNIS, Molly <class 'pandas.core.frame.Pandas'>
# TANG, Qianting <class 'pandas.core.frame.Pandas'>
# CARRARO, Martina <class 'pandas.core.frame.Pandas'>
# KATSOULIS, Sarah <class 'pandas.core.frame.Pandas'>
# WATANABE, Kanako <class 'pandas.core.frame.Pandas'>
# CHIKUNOVA, Evgeniia <class 'pandas.core.frame.Pandas'>
# LARSON, Breeja <class 'pandas.core.frame.Pandas'>
# ATKINSON, Alia <class 'pandas.core.frame.Pandas'>
# PEDERSEN, Rikke <class 'pandas.core.frame.Pandas'>
# HODGES, Chelsea <class 'pandas.core.frame.Pandas'>
# ANGIOLINI, Lisa <class 'pandas.core.frame.Pandas'>
# BIEDERMANN, Paul <class 'pandas.core.frame.Pandas'>
# IZOTOV, Danila <class 'pandas.core.frame.Pandas'>
# THORPE, Ian <class 'pandas.core.frame.Pandas'>
# RAPSYS, Danas <class 'pandas.core.frame.Pandas'>
# SUN, Yang <class 'pandas.core.frame.Pandas'>
# LOCHTE, Ryan <class 'pandas.core.frame.Pandas'>
# SCHEFFER, Fernando <class 'pandas.core.frame.Pandas'>
# SMITH, Kieran <class 'pandas.core.frame.Pandas'>
# MALYUTIN, Martin <class 'pandas.core.frame.Pandas'>
# PARK, Taehwan <class 'pandas.core.frame.Pandas'>
# LEWIS, Clyde <class 'pandas.core.frame.Pandas'>
# BERENS, Richard <class 'pandas.core.frame.Pandas'>
# KIBLER, Drew <class 'pandas.core.frame.Pandas'>
# HAAS, Townley <class 'pandas.core.frame.Pandas'>
# FRASER-HOLMES, Thomas <class 'pandas.core.frame.Pandas'>
# LOBINTSEV, Nikita <class 'pandas.core.frame.Pandas'>
# AUBOECK, Felix <class 'pandas.core.frame.Pandas'>
# VANDERKAAY, Peter <class 'pandas.core.frame.Pandas'>
# GRAHAM, Alexander <class 'pandas.core.frame.Pandas'>
# KRASNYKH, Aleksandr <class 'pandas.core.frame.Pandas'>
# DWYER, Conor <class 'pandas.core.frame.Pandas'>
# UCHIDA, Sho <class 'pandas.core.frame.Pandas'>
# DJAKOVIC, Antonio <class 'pandas.core.frame.Pandas'>
# MARTENS, Lukas <class 'pandas.core.frame.Pandas'>
# MONK, Kenrick <class 'pandas.core.frame.Pandas'>
# JI, Xinjie <class 'pandas.core.frame.Pandas'>
# GIREV, Ivan <class 'pandas.core.frame.Pandas'>
# WINNINGTON, Elijah <class 'pandas.core.frame.Pandas'>
# KOZMA, Dominik <class 'pandas.core.frame.Pandas'>
# DOVGALYUK, Mikhail <class 'pandas.core.frame.Pandas'>
# FOSTER, Carson <class 'pandas.core.frame.Pandas'>
# SETO, Daiya <class 'pandas.core.frame.Pandas'>
# MATSUDA, Takeshi <class 'pandas.core.frame.Pandas'>
# KORZENIOWSKI, Pawel <class 'pandas.core.frame.Pandas'>
# MARCHAND, Leon <class 'pandas.core.frame.Pandas'>
# SAKAI, Masato <class 'pandas.core.frame.Pandas'>
# CLARY, Tyler <class 'pandas.core.frame.Pandas'>
# KENDERESI, Tamas <class 'pandas.core.frame.Pandas'>
# HONDA, Tomoru <class 'pandas.core.frame.Pandas'>
# HOROMURA, Nao <class 'pandas.core.frame.Pandas'>
# URLANDO, Luca <class 'pandas.core.frame.Pandas'>
# SWITKOWSKI, Jan <class 'pandas.core.frame.Pandas'>
# BURMESTER, Moss <class 'pandas.core.frame.Pandas'>
# KAWECKI, Radoslaw <class 'pandas.core.frame.Pandas'>
# TANG, Muhan <class 'pandas.core.frame.Pandas'>
# ALMEIDA, Kaio Marcio <class 'pandas.core.frame.Pandas'>
# BURDISSO, Federico <class 'pandas.core.frame.Pandas'>
# SKVORTSOV, Nikolay <class 'pandas.core.frame.Pandas'>
# JUKIC, Dinko <class 'pandas.core.frame.Pandas'>
# WU, Peng <class 'pandas.core.frame.Pandas'>
# JETT, Gabriel <class 'pandas.core.frame.Pandas'>
# GREENBANK, Luke <class 'pandas.core.frame.Pandas'>
# CHEN, Yin <class 'pandas.core.frame.Pandas'>
# WANG, Kuan-Hung <class 'pandas.core.frame.Pandas'>
# D'ARCY, Nick <class 'pandas.core.frame.Pandas'>
# BROMER, Viktor B <class 'pandas.core.frame.Pandas'>
# IVANOV, Antani <class 'pandas.core.frame.Pandas'>
# ROUSSEAU, Sebastien <class 'pandas.core.frame.Pandas'>
# YAMAMOTO, Takashi <class 'pandas.core.frame.Pandas'>
# CLARK, Pace Talmadge <class 'pandas.core.frame.Pandas'>
# ROCK, Michael <class 'pandas.core.frame.Pandas'>
# CHEN, Juner <class 'pandas.core.frame.Pandas'>
# ESPOSITO, Franck <class 'pandas.core.frame.Pandas'>
# WRIGHT, Justin <class 'pandas.core.frame.Pandas'>
# YAJIMA, Yuya <class 'pandas.core.frame.Pandas'>
# PEBLEY, Jacob <class 'pandas.core.frame.Pandas'>
# MCINTOSH, Summer <class 'pandas.core.frame.Pandas'>
# ISAKOVIC, Sara <class 'pandas.core.frame.Pandas'>
# WANG, Shun <class 'pandas.core.frame.Pandas'>
# DONETC, Stanislav <class 'pandas.core.frame.Pandas'>
# KALISZ, Chase <class 'pandas.core.frame.Pandas'>
# YANG, Yu <class 'pandas.core.frame.Pandas'>
# ROGAN, Markus <class 'pandas.core.frame.Pandas'>
# MANAUDOU, Laure <class 'pandas.core.frame.Pandas'>
# LI, Guangyuan <class 'pandas.core.frame.Pandas'>
# SUNAMA, Keita <class 'pandas.core.frame.Pandas'>
# JACKSON, Joanne <class 'pandas.core.frame.Pandas'>
# PEREIRA, Thiago <class 'pandas.core.frame.Pandas'>
# LURZ, Annika <class 'pandas.core.frame.Pandas'>
# PALMER, Kylie <class 'pandas.core.frame.Pandas'>
# HEINTZ, Philip <class 'pandas.core.frame.Pandas'>
# HOFF, Katie <class 'pandas.core.frame.Pandas'>
# DESPLANCHES, Jeremy <class 'pandas.core.frame.Pandas'>
# LITCHFIELD, Max <class 'pandas.core.frame.Pandas'>
# BRODIE, Leith <class 'pandas.core.frame.Pandas'>
# DEVINE, Abrahm <class 'pandas.core.frame.Pandas'>
# KOS, Hubert <class 'pandas.core.frame.Pandas'>
# TOWNSEND, Darian <class 'pandas.core.frame.Pandas'>
# QIN, Haiyang <class 'pandas.core.frame.Pandas'>
# RODRIGUES, Henrique <class 'pandas.core.frame.Pandas'>
# GODDARD, James <class 'pandas.core.frame.Pandas'>
# RAZZETTI, Alberto <class 'pandas.core.frame.Pandas'>
# PRENOT, Josh <class 'pandas.core.frame.Pandas'>
# DESCENZA, Mary <class 'pandas.core.frame.Pandas'>
# HOSHI, Natsumi <class 'pandas.core.frame.Pandas'>
# BELMONTE, Mireia <class 'pandas.core.frame.Pandas'>
# HENTKE, Franziska <class 'pandas.core.frame.Pandas'>
# LOWE, Jemma <class 'pandas.core.frame.Pandas'>
# GONG, Jie <class 'pandas.core.frame.Pandas'>
# THOMAS, Alys Margaret <class 'pandas.core.frame.Pandas'>
# PANZIERA, Margherita <class 'pandas.core.frame.Pandas'>
# JEDRZEJCZAK, Otylia <class 'pandas.core.frame.Pandas'>
# FLICKINGER, Hali <class 'pandas.core.frame.Pandas'>
# HERSEY, Kathleen <class 'pandas.core.frame.Pandas'>
# O'NEILL, Susie <class 'pandas.core.frame.Pandas'>
# HYMAN, Misty <class 'pandas.core.frame.Pandas'>
# ADAMS, Cammile <class 'pandas.core.frame.Pandas'>
# STUBBLETY-COOK, Zac <class 'pandas.core.frame.Pandas'>
# LACROIX, Audrey <class 'pandas.core.frame.Pandas'>
# MEAGHER, Mary T <class 'pandas.core.frame.Pandas'>
# DI RADO, Maya <class 'pandas.core.frame.Pandas'>
# HAMILL, Samantha <class 'pandas.core.frame.Pandas'>
# HOCKING, Belinda <class 'pandas.core.frame.Pandas'>
# RICE, Stephanie <class 'pandas.core.frame.Pandas'>
# HOELZER, Margaret <class 'pandas.core.frame.Pandas'>
# KUKORS, Ariana <class 'pandas.core.frame.Pandas'>
# BEISEL, Elizabeth <class 'pandas.core.frame.Pandas'>
# PELTON, Elizabeth <class 'pandas.core.frame.Pandas'>
# ZHOU, Yilin <class 'pandas.core.frame.Pandas'>
# HASEGAWA, Suzuka <class 'pandas.core.frame.Pandas'>
# THOMAS, Petria <class 'pandas.core.frame.Pandas'>
# SATO, Shoma <class 'pandas.core.frame.Pandas'>
# HAYASHI, Kina <class 'pandas.core.frame.Pandas'>
# MEHLHORN, Annika <class 'pandas.core.frame.Pandas'>
# ZHAO, Jing <class 'pandas.core.frame.Pandas'>
# KAPAS, Boglarka <class 'pandas.core.frame.Pandas'>
# GIACCHETTI, Caterina <class 'pandas.core.frame.Pandas'>
# NAKANISHI, Yuko <class 'pandas.core.frame.Pandas'>
# PENG, Xuwei <class 'pandas.core.frame.Pandas'>
# DRABOT, Katie <class 'pandas.core.frame.Pandas'>
# SZILAGYI, Liliana <class 'pandas.core.frame.Pandas'>
# EGERSZEGI, Krisztina <class 'pandas.core.frame.Pandas'>
# IGNACIO, Judit <class 'pandas.core.frame.Pandas'>
# WILSON, Matthew <class 'pandas.core.frame.Pandas'>
# WATANABE, Ippei <class 'pandas.core.frame.Pandas'>
# AN, Sehyeon <class 'pandas.core.frame.Pandas'>
# KOVACS, Emese <class 'pandas.core.frame.Pandas'>
# VANDENBERG, Kim <class 'pandas.core.frame.Pandas'>
# SIMMONDS, Elizabeth <class 'pandas.core.frame.Pandas'>
# CALDWELL, Hilary <class 'pandas.core.frame.Pandas'>
# USTINOVA, Daria K <class 'pandas.core.frame.Pandas'>
# YAMAGUCHI, Akihiro <class 'pandas.core.frame.Pandas'>
# NAKAMURA, Reiko <class 'pandas.core.frame.Pandas'>
# MATTSSON, Matti <class 'pandas.core.frame.Pandas'>
# WALSH, Alex <class 'pandas.core.frame.Pandas'>
# NAY, Meagen <class 'pandas.core.frame.Pandas'>
# GYURTA, Daniel <class 'pandas.core.frame.Pandas'>
# STADDEN, Isabelle <class 'pandas.core.frame.Pandas'>
# MURDOCH, Ross <class 'pandas.core.frame.Pandas'>
# JAMIESON, Michael <class 'pandas.core.frame.Pandas'>
# BALANDIN, Dmitriy <class 'pandas.core.frame.Pandas'>
# KOCH, Marco <class 'pandas.core.frame.Pandas'>
# YE, Shiwen <class 'pandas.core.frame.Pandas'>
# MURA, Ryuya <class 'pandas.core.frame.Pandas'>
# LICON, Will <class 'pandas.core.frame.Pandas'>
# PERSSON, Erik <class 'pandas.core.frame.Pandas'>
# WILLIS, Andrew <class 'pandas.core.frame.Pandas'>
# FALLON, Matt <class 'pandas.core.frame.Pandas'>
# OHASHI, Yui <class 'pandas.core.frame.Pandas'>
# HANAGURUMA, Yu <class 'pandas.core.frame.Pandas'>
# KHOMENKO, Ilya <class 'pandas.core.frame.Pandas'>
# PRIGODA, Kirill <class 'pandas.core.frame.Pandas'>
# TATEISHI, Ryo <class 'pandas.core.frame.Pandas'>
# TOMITA, Naoya <class 'pandas.core.frame.Pandas'>
# KIM, Seoyeong <class 'pandas.core.frame.Pandas'>
# COX, Madisyn <class 'pandas.core.frame.Pandas'>
# PICKREM, Sydney <class 'pandas.core.frame.Pandas'>
# MARGALIS, Melanie <class 'pandas.core.frame.Pandas'>
# HAYES, Leah <class 'pandas.core.frame.Pandas'>
# LEVERENZ, Caitlin <class 'pandas.core.frame.Pandas'>
# WOOD, Abbie <class 'pandas.core.frame.Pandas'>
# MILEY, Hannah <class 'pandas.core.frame.Pandas'>
# TERAMURA, Miho <class 'pandas.core.frame.Pandas'>
# YU, Yiting <class 'pandas.core.frame.Pandas'>
# WILSON, Alicia <class 'pandas.core.frame.Pandas'>
# GUNES, Viktoria <class 'pandas.core.frame.Pandas'>
# KANETO, Rie <class 'pandas.core.frame.Pandas'>
# SUZUKI, Satomi <class 'pandas.core.frame.Pandas'>
# RENSHAW, Molly <class 'pandas.core.frame.Pandas'>
# MCKEOWN, Taylor <class 'pandas.core.frame.Pandas'>
# HIGL, Nadja <class 'pandas.core.frame.Pandas'>
# SUMRALL, Micah <class 'pandas.core.frame.Pandas'>
# SHI, Jinglin <class 'pandas.core.frame.Pandas'>
# JUKIC, Mirna <class 'pandas.core.frame.Pandas'>
# ESCOBEDO, Emily <class 'pandas.core.frame.Pandas'>
# MAMIE, Lisa <class 'pandas.core.frame.Pandas'>
# CORBETT, Kaylene <class 'pandas.core.frame.Pandas'>
# ULYETT, Jocelyn Kate <class 'pandas.core.frame.Pandas'>
# STRAUCH, Jenna <class 'pandas.core.frame.Pandas'>
# SMITH, Kierra <class 'pandas.core.frame.Pandas'>
# HOSTMAN, Joline <class 'pandas.core.frame.Pandas'>
# TUTTON, Chloe <class 'pandas.core.frame.Pandas'>
# BEARD, Amanda <class 'pandas.core.frame.Pandas'>
# VALL MONTERO, Jessica <class 'pandas.core.frame.Pandas'>
# MELLOULI, Ous <class 'pandas.core.frame.Pandas'>
# ZHANG, Lin <class 'pandas.core.frame.Pandas'>
# HORTON, Mack <class 'pandas.core.frame.Pandas'>
# HACKETT, Grant <class 'pandas.core.frame.Pandas'>
# JENSEN, Larsen <class 'pandas.core.frame.Pandas'>
# DETTI, Gabriele <class 'pandas.core.frame.Pandas'>
# MCLOUGHLIN, Jack Alan <class 'pandas.core.frame.Pandas'>
# COSTA, Guilherme <class 'pandas.core.frame.Pandas'>
# HAFNAOUI, Ahmed <class 'pandas.core.frame.Pandas'>
# ROSOLINO, Massimiliano <class 'pandas.core.frame.Pandas'>
# COCHRANE, Ryan <class 'pandas.core.frame.Pandas'>
# MUHLLEITNER, Henning Bennet <class 'pandas.core.frame.Pandas'>
# MCKEON, David <class 'pandas.core.frame.Pandas'>
# JAEGER, Connor <class 'pandas.core.frame.Pandas'>
# PERKINS, Kieren <class 'pandas.core.frame.Pandas'>
# PRILUKOV, Yuriy <class 'pandas.core.frame.Pandas'>
# KELLER, Klete <class 'pandas.core.frame.Pandas'>
# DE TULLIO, Marco <class 'pandas.core.frame.Pandas'>
# SHORT, Samuel Jack <class 'pandas.core.frame.Pandas'>
# WELLBROCK, Florian <class 'pandas.core.frame.Pandas'>
# GLAESNER, Mads <class 'pandas.core.frame.Pandas'>
# GROTHE, Zane <class 'pandas.core.frame.Pandas'>
# NEILL, Thomas <class 'pandas.core.frame.Pandas'>
# HAO, Yun <class 'pandas.core.frame.Pandas'>
# VOGEL, Florian Stefan <class 'pandas.core.frame.Pandas'>
# SMITH, Leah <class 'pandas.core.frame.Pandas'>
# ADLINGTON, Rebecca <class 'pandas.core.frame.Pandas'>
# LI, Bingjie <class 'pandas.core.frame.Pandas'>
# CARLIN, Jaz <class 'pandas.core.frame.Pandas'>
# KESELY, Ajna <class 'pandas.core.frame.Pandas'>
# PALLISTER, Lani <class 'pandas.core.frame.Pandas'>
# FAIRWEATHER, Erika <class 'pandas.core.frame.Pandas'>
# DE VRIESE, Laurien <class 'pandas.core.frame.Pandas'>
# COSTA, Melani <class 'pandas.core.frame.Pandas'>
# VAN ROUWENDAAL, Sharon <class 'pandas.core.frame.Pandas'>
# CAO, Yue <class 'pandas.core.frame.Pandas'>
# MELVERTON, Kiah <class 'pandas.core.frame.Pandas'>
# WANG, Jianjiahe <class 'pandas.core.frame.Pandas'>
# GOSE, Isabel <class 'pandas.core.frame.Pandas'>
# BALMY, Coralie <class 'pandas.core.frame.Pandas'>
# ASHWOOD, Jessica <class 'pandas.core.frame.Pandas'>
# QUADARELLA, Simona <class 'pandas.core.frame.Pandas'>
# POTEC, Camelia <class 'pandas.core.frame.Pandas'>
# MACLEAN, Brittany <class 'pandas.core.frame.Pandas'>
# BOYLE, Lauren <class 'pandas.core.frame.Pandas'>
# VERRASZTO, David <class 'pandas.core.frame.Pandas'>
# CLAREBURT, Lewis <class 'pandas.core.frame.Pandas'>
# LITHERLAND, Jay <class 'pandas.core.frame.Pandas'>
# SMITH, Brendon Peter <class 'pandas.core.frame.Pandas'>
# BORODIN, Ilia <class 'pandas.core.frame.Pandas'>
# MARIN, Luca <class 'pandas.core.frame.Pandas'>
# YANG, Zhixian <class 'pandas.core.frame.Pandas'>
# KIS, Gergo <class 'pandas.core.frame.Pandas'>
# HUANG, Chaosheng <class 'pandas.core.frame.Pandas'>
# HORIHATA, Yuya <class 'pandas.core.frame.Pandas'>
# FINKE, Bobby <class 'pandas.core.frame.Pandas'>
# BOGGIATTO, Alessio <class 'pandas.core.frame.Pandas'>
# HOLLO, Balazs <class 'pandas.core.frame.Pandas'>
# FUJIMORI, Takeharu <class 'pandas.core.frame.Pandas'>
# WALLACE, Daniel <class 'pandas.core.frame.Pandas'>
# ZHENG, Rongrong <class 'pandas.core.frame.Pandas'>
# OVERHOLT, Emily <class 'pandas.core.frame.Pandas'>
# GRIMES, Katie <class 'pandas.core.frame.Pandas'>
# WEYANT, Emma <class 'pandas.core.frame.Pandas'>
# LI, Xuanxu <class 'pandas.core.frame.Pandas'>
# WILLMOTT, Aimee <class 'pandas.core.frame.Pandas'>
# ZHOU, Min <class 'pandas.core.frame.Pandas'>
# KLOCHKOVA, Yana <class 'pandas.core.frame.Pandas'>
# LESAFFRE, Fantine <class 'pandas.core.frame.Pandas'>
# FILIPPI, Alessia <class 'pandas.core.frame.Pandas'>
# CUSINATO, Ilaria <class 'pandas.core.frame.Pandas'>
# SHIMIZU, Sakiko <class 'pandas.core.frame.Pandas'>
# MCHUGH, Ally <class 'pandas.core.frame.Pandas'>
# SANDENO, Kaitlin <class 'pandas.core.frame.Pandas'>
# FORDE, Brooke <class 'pandas.core.frame.Pandas'>
# PALTRINIERI, Gregorio <class 'pandas.core.frame.Pandas'>
# ROMANCHUK, Mykhailo <class 'pandas.core.frame.Pandas'>
# CHRISTIANSEN, Henrik <class 'pandas.core.frame.Pandas'>
# WOJDAK, Wojciech <class 'pandas.core.frame.Pandas'>
# AUBRY, David <class 'pandas.core.frame.Pandas'>
# GALOSSI, Lorenzo <class 'pandas.core.frame.Pandas'>
# MC BROOM, Michael <class 'pandas.core.frame.Pandas'>
# COLBERTALDO, Federico <class 'pandas.core.frame.Pandas'>
# DAVIES, David <class 'pandas.core.frame.Pandas'>
# FROLOV, Sergii <class 'pandas.core.frame.Pandas'>
# WILIMOVSKY, Jordan <class 'pandas.core.frame.Pandas'>
# JOENSEN, Pal <class 'pandas.core.frame.Pandas'>
# GRGIC, Franko <class 'pandas.core.frame.Pandas'>
# WIFFEN, Daniel <class 'pandas.core.frame.Pandas'>
# MILNE, Stephen <class 'pandas.core.frame.Pandas'>
# LA TOURETTE, Chad <class 'pandas.core.frame.Pandas'>
# SCHWARZ, Sven <class 'pandas.core.frame.Pandas'>
# ACERENZA, Domenico <class 'pandas.core.frame.Pandas'>
# HARRISON, Jordan <class 'pandas.core.frame.Pandas'>
# JOLY, Damien <class 'pandas.core.frame.Pandas'>
# STANCZYK, Przemyslaw <class 'pandas.core.frame.Pandas'>
# FRIIS, Lotte <class 'pandas.core.frame.Pandas'>
# EVANS, Janet <class 'pandas.core.frame.Pandas'>
# WELLBROCK, Sarah <class 'pandas.core.frame.Pandas'>
# ZIEGLER, Kate <class 'pandas.core.frame.Pandas'>
# KIRPICHNIKOVA, Anastasiia <class 'pandas.core.frame.Pandas'>
# XIN, Xin <class 'pandas.core.frame.Pandas'>
# MOHRING, Anke <class 'pandas.core.frame.Pandas'>
# BENNETT, Brooke <class 'pandas.core.frame.Pandas'>
# ANDERSON, Haley <class 'pandas.core.frame.Pandas'>
# ZHANG, Yuhan <class 'pandas.core.frame.Pandas'>
# SAWRYMOWICZ, Mateusz <class 'pandas.core.frame.Pandas'>
# JERVIS, Daniel <class 'pandas.core.frame.Pandas'>
# NORGAARD, Alexander <class 'pandas.core.frame.Pandas'>
# MICKA, Jan <class 'pandas.core.frame.Pandas'>
# HOFFMANN, Joerg <class 'pandas.core.frame.Pandas'>
# KLEMET, Oliver <class 'pandas.core.frame.Pandas'>
# SULLIVAN, Erica <class 'pandas.core.frame.Pandas'>
# GOUGH, Maddy <class 'pandas.core.frame.Pandas'>
# PIGNATIELLO, Delfina <class 'pandas.core.frame.Pandas'>
# TWICHELL, Ashley <class 'pandas.core.frame.Pandas'>
# KOBRICH, Kristel <class 'pandas.core.frame.Pandas'>
# TUNCEL, Merve <class 'pandas.core.frame.Pandas'>
# RIGAMONTI, Flavia <class 'pandas.core.frame.Pandas'>
# JOHNSON, Moesha <class 'pandas.core.frame.Pandas'>
# CARAMIGNOLI, Martina Rita <class 'pandas.core.frame.Pandas'>
# PEIRSOL, Hayley <class 'pandas.core.frame.Pandas'>
# SHIBATA, Ai <class 'pandas.core.frame.Pandas'>
# LEE, Kareena <class 'pandas.core.frame.Pandas'>
# STOCKBAUER, Hannah <class 'pandas.core.frame.Pandas'>
# VILLAECIJA, Erika <class 'pandas.core.frame.Pandas'>
# XU, Danlu <class 'pandas.core.frame.Pandas'>
# VILAS, Maria <class 'pandas.core.frame.Pandas'>
# NORDIN, Emma Ayasha <class 'pandas.core.frame.Pandas'>
# GORMAN, Melissa <class 'pandas.core.frame.Pandas'>
# SHAO, Yiwen <class 'pandas.core.frame.Pandas'>
# MIHALYVARI-FARKAS, Viktoria <class 'pandas.core.frame.Pandas'>
# MURPHY, Grainne <class 'pandas.core.frame.Pandas'>

# %%
# #### Close the MongoDB connection

client.close()
